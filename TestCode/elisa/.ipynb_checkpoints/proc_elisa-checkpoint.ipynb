# %%
import numpy as np
import psana as ps
import sys
import os
os.environ['PS_SRV_NODES'] = '1' #added for SLURM

from mpi4py import MPI
comm = MPI.COMM_WORLD
rank = comm.Get_rank()
size = comm.Get_size()
from scipy.ndimage.filters import gaussian_filter

def sum_ANDOR(l):
    return np.sum(l-np.average(l[0:500]))

#exp = 'rixx43518' # changeme
exp = 'rixlw1019' # changeme
run_number = 16 #int(sys.argv[1])

preprocessed_folder = '/reg/data/ana16/rix/%s/results/preproc/test/' % exp #changeme
filename = preprocessed_folder+'run%d_v1.h5' % run_number #changeme
if (os.path.isfile(filename) or os.path.isfile(filename.split('.')[0]+'_part0.h5')):
    raise ValueError('h5 files for run %d already exist! check folder: %s'%(run_number, preprocessed_folder))
    #not sure which one to check for so check for both

ds = ps.DataSource(exp=exp, run=run_number)
smd = ds.smalldata(filename=filename)

update = 50 # Print update (per core)
default_val = -9999.0

##########################################
Nfound = 0
Nbad = 0
times = None
##########################################
atm_roi_x = [200,800]
atm_roi_y = [0,1024]

#run.detinfo to see variables
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_25887/3146195707.py in <module>
#      21 filename = preprocessed_folder+'run%d_v1.h5' % run_number #changeme
#      22 if (os.path.isfile(filename) or os.path.isfile(filename.split('.')[0]+'_part0.h5')):
# ---> 23     raise ValueError('h5 files for run %d already exist! check folder: %s'%(run_number, preprocessed_folder))
#      24     #not sure which one to check for so check for both
#      25
#
# ValueError: h5 files for run 16 already exist! check folder: /reg/data/ana16/rix/rixlw1019/results/preproc/test/

# %%
#dir(ds.runs)
dir(ds)
#
dir(ds.runs)
myrun = next(ds.runs())

# %%
print(ds.xtc_path)
# Out:
# /reg/d/psdm/rix/rixlw1019/xtc

# %%
dir(myrun)
# Out:
# ['Detector',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_empty_calibconst',
#  '_dets',
#  '_evt',
#  '_evt_iter',
#  '_get_runinfo',
#  '_get_valid_env_var_name',
#  '_setup_envstore',
#  'analyze',
#  'beginruns',
#  'c_ana',
#  'configs',
#  'detinfo',
#  'detnames',
#  'dm',
#  'dsparms',
#  'epicsinfo',
#  'esm',
#  'events',
#  'expt',
#  'id',
#  'nfiles',
#  'run',
#  'runnum',
#  'scan',
#  'scaninfo',
#  'smd_dm',
#  'smd_fds',
#  'step',
#  'steps',
#  'timestamp',
#  'xtcinfo']

# %%
for run in ds.runs():
    print(dir(run))
#why print works only the first time?

# %%
run.detinfo
# Out:
# {('rix_fim1', 'fex'): ['base_0',
#   'base_1',
#   'base_2',
#   'base_3',
#   'base_4',
#   'base_5',
#   'base_6',
#   'base_7',
#   'integral_0',
#   'integral_1',
#   'integral_2',
#   'integral_3',
#   'integral_4',
#   'integral_5',
#   'integral_6',
#   'integral_7',
#   'intensity',
#   'itrigCount',
#   'posX',
#   'posY',
#   'ptrigCount'],
#  ('rix_fim1', 'raw'): ['raw_0',
#   'raw_1',
#   'raw_2',
#   'raw_3',
#   'raw_4',
#   'raw_5',
#   'raw_6',
#   'raw_7'],
#  ('hsd', 'raw'): ['padded', 'peak_times', 'peaks', 'waveforms'],
#  ('epicsinfo', 'epicsinfo'): [],
#  ('andor_dir', 'raw'): ['value'],
#  ('xgmd', 'raw'): ['avgIntensity',
#   'electron1BkgNoiseAvg',
#   'electron2BkgNoiseAvg',
#   'energy',
#   'rmsElectronSum',
#   'xpos',
#   'ypos'],
#  ('gmd', 'raw'): ['avgIntensity',
#   'electron1BkgNoiseAvg',
#   'electron2BkgNoiseAvg',
#   'energy',
#   'rmsElectronSum',
#   'xpos',
#   'ypos'],
#  ('ebeam', 'raw'): ['damageMask',
#   'ebeamCharge',
#   'ebeamDumpCharge',
#   'ebeamEnergyBC1',
#   'ebeamEnergyBC2',
#   'ebeamL3Energy',
#   'ebeamLTU250',
#   'ebeamLTU450',
#   'ebeamLTUAngY',
#   'ebeamLTUPosX',
#   'ebeamLTUPosY',
#   'ebeamLUTAngX',
#   'ebeamPhotonEnergy',
#   'ebeamPkCurrBC1',
#   'ebeamPkCurrBC2',
#   'ebeamUndAngX',
#   'ebeamUndAngY',
#   'ebeamUndPosX',
#   'ebeamUndPosY',
#   'ebeamXTCAVAmpl',
#   'ebeamXTCAVPhase'],
#  ('mono_encoder', 'raw'): ['value'],
#  ('manta', 'raw'): ['value'],
#  ('rix_fim2', 'fex'): ['base_0',
#   'base_1',
#   'base_2',
#   'base_3',
#   'base_4',
#   'base_5',
#   'base_6',
#   'base_7',
#   'integral_0',
#   'integral_1',
#   'integral_2',
#   'integral_3',
#   'integral_4',
#   'integral_5',
#   'integral_6',
#   'integral_7',
#   'intensity',
#   'itrigCount',
#   'posX',
#   'posY',
#   'ptrigCount'],
#  ('rix_fim2', 'raw'): ['raw_0',
#   'raw_1',
#   'raw_2',
#   'raw_3',
#   'raw_4',
#   'raw_5',
#   'raw_6',
#   'raw_7'],
#  ('rix_fim0', 'fex'): ['base_0',
#   'base_1',
#   'base_2',
#   'base_3',
#   'base_4',
#   'base_5',
#   'base_6',
#   'base_7',
#   'integral_0',
#   'integral_1',
#   'integral_2',
#   'integral_3',
#   'integral_4',
#   'integral_5',
#   'integral_6',
#   'integral_7',
#   'intensity',
#   'itrigCount',
#   'posX',
#   'posY',
#   'ptrigCount'],
#  ('rix_fim0', 'raw'): ['raw_0',
#   'raw_1',
#   'raw_2',
#   'raw_3',
#   'raw_4',
#   'raw_5',
#   'raw_6',
#   'raw_7'],
#  ('timing', 'raw'): ['eventcodes'],
#  ('atmopal', 'ttfex'): ['ampl',
#   'amplnxt',
#   'calib',
#   'fltpos',
#   'fltpos_ps',
#   'fltposfwhm',
#   'image',
#   'proj_ref',
#   'proj_sig',
#   'raw',
#   'refampl'],
#  ('atmopal', 'raw'): ['calib', 'image', 'raw']}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_8656/2181332308.py in <module>
# ----> 1 ds.runs[0]
#
# TypeError: 'method' object is not subscriptable

# %%
# #####################################################
for run in ds.runs():
    
    # detectors - epics defined below
    timing = run.Detector("timing")
    if ('rix_fim2', 'raw') in run.detinfo:
        rix_fim2 = run.Detector('rix_fim2')
    else: print('No fim2')
    if ('rix_fim1', 'raw') in run.detinfo:
        rix_fim1 = run.Detector('rix_fim1')
    else: print('No fim1')
    if ('rix_fim0', 'raw') in run.detinfo:
        rix_fim0 = run.Detector('rix_fim0')
    else: print('No fim0')
    if ('xgmd','raw') in run.detinfo:
        xgmd = run.Detector('xgmd')
    else: print('No xgmd')
    if ('gmd','raw') in run.detinfo:
        gmd = run.Detector('gmd')
    else: print('No gmd')
    if ('andor_dir','raw') in run.detinfo:
        andor = run.Detector('andor_dir')
    else: print('No andor')
    if ('ebeam', 'raw') in run.detinfo:
        ebeam = run.Detector('ebeam')
    else: print('No ebeam')
    if ('mono_encoder', 'raw') in run.detinfo:
        mono_encoder = run.Detector('mono_encoder')
    else: print('No mono encoder')
    if ('atmopal', 'raw') in run.detinfo:
        atm = run.Detector('atmopal')
    else: print('No atm')
    
    if hasattr(run, 'epicsinfo'):
        epics_strs = [item[0] for item in run.epicsinfo.keys()][1:] # first one is weird
        epics_detectors = [run.Detector(item) for item in epics_strs]

    for nevent, event in enumerate(run.events()):
        
        if nevent%update==0: print("Event number: %d, Valid shots: %d" % (nevent, Nfound))
            
        data = {'epics_'+epic_str: epic_det(event) for epic_str, epic_det in zip(epics_strs, epics_detectors)}
        
        if any(type(val) not in [int, float] for val in data.values()):
            print("Bad EPICS: %d" % nevent)
            Nbad += 1
            continue

        if ('andor_dir','raw') in run.detinfo:
            andor_data = andor.raw.value(event)
            if andor_data is None:
                print("andor: %d" % nevent)
                Nbad += 1
                continue   
        if ('mono_encoder', 'raw') in run.detinfo:
            mono_data = mono_encoder.raw.value(event)
            if mono_data is None:
                print("Mono encoder: %d" % nevent)
                Nbad += 1
                continue 

        evrs = timing.raw.eventcodes(event)
        if evrs is None:
            print("Bad EVRs: %d" % nevent)
            Nbad += 1
            continue
        evrs = np.array(evrs)
        if evrs.dtype == int:
            data['evrs'] = evrs.copy()
        else:
            print("Bad EVRs: %d" % nevent)
        
        bad = False
        for (detname, method), attribs in run.detinfo.items():
            
            if (detname not in ['timing', 'hsd', 'andor','andor_dir','andor_vls', 'epicsinfo', 'atmopal', 'xtcav', 'manta']) and not \
            (detname=='rix_fim0' and method=='raw') and not (detname=='rix_fim1' and method=='raw') and not \
            (detname=='rix_fim2' and method=='raw'):
                for attrib in attribs:
                    #print(detname, method, attrib)
                    val = getattr(getattr(locals()[detname], method), attrib)(event)
                    if val is None:
                        if detname in ['ebeam', 'gmd', 'xgmd'] and evrs[161]: # BYKIK gives None for these, but we still want to process the shots
                            val = default_val
                        else:
                            bad = True
                            print("Bad %s: %d" % (detname, nevent))
                            Nbad += 1
                            break
                    data[detname+'_'+attrib] = val
        if bad:
            continue

        #ANDOR:
        if ('andor_dir','raw') in run.detinfo:
            andor_data = andor_data.mean(0)
            data['andor'] = andor_data.copy()
            data['andor_sum'] = sum_ANDOR(andor_data)

        # Monochromator encoder
        if ('mono_encoder', 'raw') in run.detinfo:
            print(mono_data)
            data['mono_encoder'] = mono_data.copy()
        
        if ('atmopal', 'raw') in run.detinfo:
            atmim = atm.raw.image(event)
            atm_lo_x = np.average(atmim[atm_roi_x[0]:atm_roi_x[1],atm_roi_y[0]:atm_roi_y[1]],axis = 0)
            atm_lo_y = np.average(atmim[atm_roi_x[0]:atm_roi_x[1],atm_roi_y[0]:atm_roi_y[1]],axis = 1)
            data['atm_lo_x'] = atm_lo_x.copy()
            data['atm_lo_y'] = atm_lo_y.copy()
            #print(atmim.shape)
        
        # time tool fex
        if ('atmopal','ttfex') in run.detinfo:
            for ii, attribute in enumerate(run.detinfo[('atmopal','ttfex')]):
                #print(attribute)
                if attribute not in ['calib','image','raw']:
                    val = getattr(atm.ttfex,attribute)(event)
                    if val is None:
                        print("Bad ttfex {:}: {:}".format(attribute,nevent))
                        data['ttfex_'+attribute] = -9999.0
                    else:
                        data['ttfex_'+attribute] = val

        # I0 Monitors
        if ('rix_fim0', 'raw') in run.detinfo:
            fim0_raw = np.zeros((8,256))
            for ii, attribute in enumerate(run.detinfo[('rix_fim0', 'raw')]):
                fim_tmp = getattr(rix_fim0.raw,attribute)(event)
                if fim_tmp is None:
                    print("Bad fim0 {:}: {:}".format(attribute,nevent))
                    Nbad += 1
                    continue  
                fim0_raw[ii,:] = fim_tmp
            data['fim0_raw'] = fim0_raw.copy()
        
        if ('rix_fim1', 'raw') in run.detinfo:
            fim1_raw = np.zeros((8,256))
            for ii, attribute in enumerate(run.detinfo[('rix_fim1', 'raw')]):
                fim_tmp = getattr(rix_fim1.raw,attribute)(event)
                if fim_tmp is None:
                    print("Bad fim0 {:}: {:}".format(attribute,nevent))
                    Nbad += 1
                    continue  
                fim1_raw[ii,:] = fim_tmp
            data['fim1_raw'] = fim1_raw.copy()
        
        if ('rix_fim2', 'raw') in run.detinfo:
            fim2_raw = np.zeros((8,256))
            for ii, attribute in enumerate(run.detinfo[('rix_fim2', 'raw')]):
                fim_tmp = getattr(rix_fim2.raw,attribute)(event)
                if fim_tmp is None:
                    print("Bad fim0 {:}: {:}".format(attribute,nevent))
                    Nbad += 1
                    continue  
                fim2_raw[ii,:] = fim_tmp
            data['fim2_raw'] = fim2_raw.copy()
                
        valid_data = True
        for key, val in data.items():
            if (type(val) not in [int, float]) and (not hasattr(val, 'dtype')):
                print("Bad data:", key)
                valid_data = False
                break
        
        if valid_data:
            smd.event(event, **data)
            Nfound += 1
        else:
            Nbad += 1
            continue
        
if smd.summary:
    Nbad = smd.sum(Nbad)
    Nfound = smd.sum(Nfound)
    smd.save_summary(Nfound=Nfound, Nbad=Nbad)
    
smd.done()
    
#if rank == (size - 1):
#    perms = '444' # fo-fo-fo
#    for f in [filename.split('.')[0]+'_part0.h5', filename]:
#        os.chmod(f, int(perms, base=8))
# Out:
# Event number: 0, Valid shots: 0
# Bad EPICS: 0
# Bad EPICS: 1
# Bad EPICS: 2
# Bad EPICS: 3
# Bad EPICS: 4
# Bad EPICS: 5
# Bad EPICS: 6
# Bad EPICS: 7
# Bad EPICS: 8
# Bad EPICS: 9
# Bad EPICS: 10
# Bad EPICS: 11
# Bad EPICS: 12
# Bad EPICS: 13
# Bad EPICS: 14
# Bad EPICS: 15
# Bad EPICS: 16
# Bad EPICS: 17
# Bad EPICS: 18
# Bad EPICS: 19
# Bad EPICS: 20
# Bad EPICS: 21
# Bad EPICS: 22
# Bad EPICS: 23
# Bad EPICS: 24
# Bad EPICS: 25
# Bad EPICS: 26
# Bad EPICS: 27
# Bad EPICS: 28
# Bad EPICS: 29
# Bad EPICS: 30
# Bad EPICS: 31
# Bad EPICS: 32
# Bad EPICS: 33
# Bad EPICS: 34
# Bad EPICS: 35
# Bad EPICS: 36
# Bad EPICS: 37
# Bad EPICS: 38
# Bad EPICS: 39
# Bad EPICS: 40
# Bad EPICS: 41
# Bad EPICS: 42
# Bad EPICS: 43
# Bad EPICS: 44
# Bad EPICS: 45
# Bad EPICS: 46
# Bad EPICS: 47
# 3308.392535
# Bad ttfex ampl: 48
# Bad ttfex amplnxt: 48
# Bad ttfex fltpos: 48
# Bad ttfex fltpos_ps: 48
# Bad ttfex fltposfwhm: 48
# Bad ttfex proj_ref: 48
# Bad ttfex proj_sig: 48
# Bad ttfex refampl: 48
# 3308.539209
# Event number: 50, Valid shots: 2
# 3308.3725339999996
# 3308.5192079999997
# 3308.4925399999997
# Bad ttfex ampl: 52
# Bad ttfex amplnxt: 52
# Bad ttfex fltpos: 52
# Bad ttfex fltpos_ps: 52
# Bad ttfex fltposfwhm: 52
# Bad ttfex proj_ref: 52
# Bad ttfex proj_sig: 52
# Bad ttfex refampl: 52
# /cds/sw/ds/ana/conda2/inst/envs/ps-4.4.3/lib/python3.7/site-packages/psana/detector/misc_detectors.py:67: RuntimeWarning: overflow encountered in uint_scalars
#   return segments[0].encoderValue[0]*segments[0].scale[0]*1e-6
# 3308.4592049999997
# Bad ttfex ampl: 53
# Bad ttfex amplnxt: 53
# Bad ttfex fltpos: 53
# Bad ttfex fltpos_ps: 53
# Bad ttfex fltposfwhm: 53
# Bad ttfex proj_ref: 53
# Bad ttfex proj_sig: 53
# Bad ttfex refampl: 53
# 3308.565877
# Bad ttfex ampl: 54
# Bad ttfex amplnxt: 54
# Bad ttfex fltpos: 54
# Bad ttfex fltpos_ps: 54
# Bad ttfex fltposfwhm: 54
# Bad ttfex proj_ref: 54
# Bad ttfex proj_sig: 54
# Bad ttfex refampl: 54
# 3308.412536
# Bad ttfex ampl: 55
# Bad ttfex amplnxt: 55
# Bad ttfex fltpos: 55
# Bad ttfex fltpos_ps: 55
# Bad ttfex fltposfwhm: 55
# Bad ttfex proj_ref: 55
# Bad ttfex proj_sig: 55
# Bad ttfex refampl: 55
# 3308.3792009999997
# Bad ttfex ampl: 56
# Bad ttfex amplnxt: 56
# Bad ttfex fltpos: 56
# Bad ttfex fltpos_ps: 56
# Bad ttfex fltposfwhm: 56
# Bad ttfex proj_ref: 56
# Bad ttfex proj_sig: 56
# Bad ttfex refampl: 56
# 3308.3792009999997
# Bad ttfex ampl: 57
# Bad ttfex amplnxt: 57
# Bad ttfex fltpos: 57
# Bad ttfex fltpos_ps: 57
# Bad ttfex fltposfwhm: 57
# Bad ttfex proj_ref: 57
# Bad ttfex proj_sig: 57
# Bad ttfex refampl: 57
# 3308.412536
# Bad ttfex ampl: 58
# Bad ttfex amplnxt: 58
# Bad ttfex fltpos: 58
# Bad ttfex fltpos_ps: 58
# Bad ttfex fltposfwhm: 58
# Bad ttfex proj_ref: 58
# Bad ttfex proj_sig: 58
# Bad ttfex refampl: 58
# 3308.585878
# 3308.412536
# Bad ttfex ampl: 60
# Bad ttfex amplnxt: 60
# Bad ttfex fltpos: 60
# Bad ttfex fltpos_ps: 60
# Bad ttfex fltposfwhm: 60
# Bad ttfex proj_ref: 60
# Bad ttfex proj_sig: 60
# Bad ttfex refampl: 60
# 3308.385868
# Bad ttfex ampl: 61
# Bad ttfex amplnxt: 61
# Bad ttfex fltpos: 61
# Bad ttfex fltpos_ps: 61
# Bad ttfex fltposfwhm: 61
# Bad ttfex proj_ref: 61
# Bad ttfex proj_sig: 61
# Bad ttfex refampl: 61
# 3308.4325369999997
# Bad ttfex ampl: 62
# Bad ttfex amplnxt: 62
# Bad ttfex fltpos: 62
# Bad ttfex fltpos_ps: 62
# Bad ttfex fltposfwhm: 62
# Bad ttfex proj_ref: 62
# Bad ttfex proj_sig: 62
# Bad ttfex refampl: 62
# 3308.299197
# Bad ttfex ampl: 63
# Bad ttfex amplnxt: 63
# Bad ttfex fltpos: 63
# Bad ttfex fltpos_ps: 63
# Bad ttfex fltposfwhm: 63
# Bad ttfex proj_ref: 63
# Bad ttfex proj_sig: 63
# Bad ttfex refampl: 63
# 3308.445871
# Bad ttfex ampl: 64
# Bad ttfex amplnxt: 64
# Bad ttfex fltpos: 64
# Bad ttfex fltpos_ps: 64
# Bad ttfex fltposfwhm: 64
# Bad ttfex proj_ref: 64
# Bad ttfex proj_sig: 64
# Bad ttfex refampl: 64
# 3308.439204
# Bad ttfex ampl: 65
# Bad ttfex amplnxt: 65
# Bad ttfex fltpos: 65
# Bad ttfex fltpos_ps: 65
# Bad ttfex fltposfwhm: 65
# Bad ttfex proj_ref: 65
# Bad ttfex proj_sig: 65
# Bad ttfex refampl: 65
# 3308.325865
# Bad ttfex ampl: 66
# Bad ttfex amplnxt: 66
# Bad ttfex fltpos: 66
# Bad ttfex fltpos_ps: 66
# Bad ttfex fltposfwhm: 66
# Bad ttfex proj_ref: 66
# Bad ttfex proj_sig: 66
# Bad ttfex refampl: 66
# 3308.42587
# Bad ttfex ampl: 67
# Bad ttfex amplnxt: 67
# Bad ttfex fltpos: 67
# Bad ttfex fltpos_ps: 67
# Bad ttfex fltposfwhm: 67
# Bad ttfex proj_ref: 67
# Bad ttfex proj_sig: 67
# Bad ttfex refampl: 67
# 3308.412536
# Bad ttfex ampl: 68
# Bad ttfex amplnxt: 68
# Bad ttfex fltpos: 68
# Bad ttfex fltpos_ps: 68
# Bad ttfex fltposfwhm: 68
# Bad ttfex proj_ref: 68
# Bad ttfex proj_sig: 68
# Bad ttfex refampl: 68
# 3308.505874
# Bad ttfex ampl: 69
# Bad ttfex amplnxt: 69
# Bad ttfex fltpos: 69
# Bad ttfex fltpos_ps: 69
# Bad ttfex fltposfwhm: 69
# Bad ttfex proj_ref: 69
# Bad ttfex proj_sig: 69
# Bad ttfex refampl: 69
# 3308.4925399999997
# Bad ttfex ampl: 70
# Bad ttfex amplnxt: 70
# Bad ttfex fltpos: 70
# Bad ttfex fltpos_ps: 70
# Bad ttfex fltposfwhm: 70
# Bad ttfex proj_ref: 70
# Bad ttfex proj_sig: 70
# Bad ttfex refampl: 70
# 3308.4325369999997
# Bad ttfex ampl: 71
# Bad ttfex amplnxt: 71
# Bad ttfex fltpos: 71
# Bad ttfex fltpos_ps: 71
# Bad ttfex fltposfwhm: 71
# Bad ttfex proj_ref: 71
# Bad ttfex proj_sig: 71
# Bad ttfex refampl: 71
# 3308.399202
# 3308.445871
# 3308.4658719999998
# 3308.419203
# Bad ttfex ampl: 75
# Bad ttfex amplnxt: 75
# Bad ttfex fltpos: 75
# Bad ttfex fltpos_ps: 75
# Bad ttfex fltposfwhm: 75
# Bad ttfex proj_ref: 75
# Bad ttfex proj_sig: 75
# Bad ttfex refampl: 75
# 3308.439204
# Bad ttfex ampl: 76
# Bad ttfex amplnxt: 76
# Bad ttfex fltpos: 76
# Bad ttfex fltpos_ps: 76
# Bad ttfex fltposfwhm: 76
# Bad ttfex proj_ref: 76
# Bad ttfex proj_sig: 76
# Bad ttfex refampl: 76
# 3308.439204
# Bad ttfex ampl: 77
# Bad ttfex amplnxt: 77
# Bad ttfex fltpos: 77
# Bad ttfex fltpos_ps: 77
# Bad ttfex fltposfwhm: 77
# Bad ttfex proj_ref: 77
# Bad ttfex proj_sig: 77
# Bad ttfex refampl: 77
# 3308.3525329999998
# Bad ttfex ampl: 78
# Bad ttfex amplnxt: 78
# Bad ttfex fltpos: 78
# Bad ttfex fltpos_ps: 78
# Bad ttfex fltposfwhm: 78
# Bad ttfex proj_ref: 78
# Bad ttfex proj_sig: 78
# Bad ttfex refampl: 78
# 3308.42587
# Bad ttfex ampl: 79
# Bad ttfex amplnxt: 79
# Bad ttfex fltpos: 79
# Bad ttfex fltpos_ps: 79
# Bad ttfex fltposfwhm: 79
# Bad ttfex proj_ref: 79
# Bad ttfex proj_sig: 79
# Bad ttfex refampl: 79
# 3308.452538
# Bad ttfex ampl: 80
# Bad ttfex amplnxt: 80
# Bad ttfex fltpos: 80
# Bad ttfex fltpos_ps: 80
# Bad ttfex fltposfwhm: 80
# Bad ttfex proj_ref: 80
# Bad ttfex proj_sig: 80
# Bad ttfex refampl: 80
# 3308.452538
# Bad ttfex ampl: 81
# Bad ttfex amplnxt: 81
# Bad ttfex fltpos: 81
# Bad ttfex fltpos_ps: 81
# Bad ttfex fltposfwhm: 81
# Bad ttfex proj_ref: 81
# Bad ttfex proj_sig: 81
# Bad ttfex refampl: 81
# 3308.5792109999998
# Bad ttfex ampl: 82
# Bad ttfex amplnxt: 82
# Bad ttfex fltpos: 82
# Bad ttfex fltpos_ps: 82
# Bad ttfex fltposfwhm: 82
# Bad ttfex proj_ref: 82
# Bad ttfex proj_sig: 82
# Bad ttfex refampl: 82
# 3308.312531
# Bad ttfex ampl: 83
# Bad ttfex amplnxt: 83
# Bad ttfex fltpos: 83
# Bad ttfex fltpos_ps: 83
# Bad ttfex fltposfwhm: 83
# Bad ttfex proj_ref: 83
# Bad ttfex proj_sig: 83
# Bad ttfex refampl: 83
# 3308.439204
# Bad ttfex ampl: 84
# Bad ttfex amplnxt: 84
# Bad ttfex fltpos: 84
# Bad ttfex fltpos_ps: 84
# Bad ttfex fltposfwhm: 84
# Bad ttfex proj_ref: 84
# Bad ttfex proj_sig: 84
# Bad ttfex refampl: 84
# 3308.385868
# 3308.4592049999997
# Bad ttfex ampl: 86
# Bad ttfex amplnxt: 86
# Bad ttfex fltpos: 86
# Bad ttfex fltpos_ps: 86
# Bad ttfex fltposfwhm: 86
# Bad ttfex proj_ref: 86
# Bad ttfex proj_sig: 86
# Bad ttfex refampl: 86
# 3308.399202
# Bad ttfex ampl: 87
# Bad ttfex amplnxt: 87
# Bad ttfex fltpos: 87
# Bad ttfex fltpos_ps: 87
# Bad ttfex fltposfwhm: 87
# Bad ttfex proj_ref: 87
# Bad ttfex proj_sig: 87
# Bad ttfex refampl: 87
# 3308.499207
# Bad ttfex ampl: 88
# Bad ttfex amplnxt: 88
# Bad ttfex fltpos: 88
# Bad ttfex fltpos_ps: 88
# Bad ttfex fltposfwhm: 88
# Bad ttfex proj_ref: 88
# Bad ttfex proj_sig: 88
# Bad ttfex refampl: 88
# 3308.385868
# Bad ttfex ampl: 89
# Bad ttfex amplnxt: 89
# Bad ttfex fltpos: 89
# Bad ttfex fltpos_ps: 89
# Bad ttfex fltposfwhm: 89
# Bad ttfex proj_ref: 89
# Bad ttfex proj_sig: 89
# Bad ttfex refampl: 89
# 3308.3458659999997
# Bad ttfex ampl: 90
# Bad ttfex amplnxt: 90
# Bad ttfex fltpos: 90
# Bad ttfex fltpos_ps: 90
# Bad ttfex fltposfwhm: 90
# Bad ttfex proj_ref: 90
# Bad ttfex proj_sig: 90
# Bad ttfex refampl: 90
# 3308.4658719999998
# Bad ttfex ampl: 91
# Bad ttfex amplnxt: 91
# Bad ttfex fltpos: 91
# Bad ttfex fltpos_ps: 91
# Bad ttfex fltposfwhm: 91
# Bad ttfex proj_ref: 91
# Bad ttfex proj_sig: 91
# Bad ttfex refampl: 91
# 3308.4925399999997
# 3308.4658719999998
# Bad ttfex ampl: 93
# Bad ttfex amplnxt: 93
# Bad ttfex fltpos: 93
# Bad ttfex fltpos_ps: 93
# Bad ttfex fltposfwhm: 93
# Bad ttfex proj_ref: 93
# Bad ttfex proj_sig: 93
# Bad ttfex refampl: 93
# 3308.385868
# Bad ttfex ampl: 94
# Bad ttfex amplnxt: 94
# Bad ttfex fltpos: 94
# Bad ttfex fltpos_ps: 94
# Bad ttfex fltposfwhm: 94
# Bad ttfex proj_ref: 94
# Bad ttfex proj_sig: 94
# Bad ttfex refampl: 94
# 3308.385868
# Bad ttfex ampl: 95
# Bad ttfex amplnxt: 95
# Bad ttfex fltpos: 95
# Bad ttfex fltpos_ps: 95
# Bad ttfex fltposfwhm: 95
# Bad ttfex proj_ref: 95
# Bad ttfex proj_sig: 95
# Bad ttfex refampl: 95
# 3308.479206
# Bad ttfex ampl: 96
# Bad ttfex amplnxt: 96
# Bad ttfex fltpos: 96
# Bad ttfex fltpos_ps: 96
# Bad ttfex fltposfwhm: 96
# Bad ttfex proj_ref: 96
# Bad ttfex proj_sig: 96
# Bad ttfex refampl: 96
# 3308.445871
# 3308.5458759999997
# Bad ttfex ampl: 98
# Bad ttfex amplnxt: 98
# Bad ttfex fltpos: 98
# Bad ttfex fltpos_ps: 98
# Bad ttfex fltposfwhm: 98
# Bad ttfex proj_ref: 98
# Bad ttfex proj_sig: 98
# Bad ttfex refampl: 98
# 3308.305864
# Bad ttfex ampl: 99
# Bad ttfex amplnxt: 99
# Bad ttfex fltpos: 99
# Bad ttfex fltpos_ps: 99
# Bad ttfex fltposfwhm: 99
# Bad ttfex proj_ref: 99
# Bad ttfex proj_sig: 99
# Bad ttfex refampl: 99
# Event number: 100, Valid shots: 52
# 3308.445871
# Bad ttfex ampl: 100
# Bad ttfex amplnxt: 100
# Bad ttfex fltpos: 100
# Bad ttfex fltpos_ps: 100
# Bad ttfex fltposfwhm: 100
# Bad ttfex proj_ref: 100
# Bad ttfex proj_sig: 100
# Bad ttfex refampl: 100
# 3308.4325369999997
# 3308.4058689999997
# Bad ttfex ampl: 102
# Bad ttfex amplnxt: 102
# Bad ttfex fltpos: 102
# Bad ttfex fltpos_ps: 102
# Bad ttfex fltposfwhm: 102
# Bad ttfex proj_ref: 102
# Bad ttfex proj_sig: 102
# Bad ttfex refampl: 102
# 3308.452538
# Bad ttfex ampl: 103
# Bad ttfex amplnxt: 103
# Bad ttfex fltpos: 103
# Bad ttfex fltpos_ps: 103
# Bad ttfex fltposfwhm: 103
# Bad ttfex proj_ref: 103
# Bad ttfex proj_sig: 103
# Bad ttfex refampl: 103
# 3308.312531
# Bad ttfex ampl: 104
# Bad ttfex amplnxt: 104
# Bad ttfex fltpos: 104
# Bad ttfex fltpos_ps: 104
# Bad ttfex fltposfwhm: 104
# Bad ttfex proj_ref: 104
# Bad ttfex proj_sig: 104
# Bad ttfex refampl: 104
# 3308.4325369999997
# Bad ttfex ampl: 105
# Bad ttfex amplnxt: 105
# Bad ttfex fltpos: 105
# Bad ttfex fltpos_ps: 105
# Bad ttfex fltposfwhm: 105
# Bad ttfex proj_ref: 105
# Bad ttfex proj_sig: 105
# Bad ttfex refampl: 105
# 3308.339199
# Bad ttfex ampl: 106
# Bad ttfex amplnxt: 106
# Bad ttfex fltpos: 106
# Bad ttfex fltpos_ps: 106
# Bad ttfex fltposfwhm: 106
# Bad ttfex proj_ref: 106
# Bad ttfex proj_sig: 106
# Bad ttfex refampl: 106
# 3308.4592049999997
# Bad ttfex ampl: 107
# Bad ttfex amplnxt: 107
# Bad ttfex fltpos: 107
# Bad ttfex fltpos_ps: 107
# Bad ttfex fltposfwhm: 107
# Bad ttfex proj_ref: 107
# Bad ttfex proj_sig: 107
# Bad ttfex refampl: 107
# 3308.4658719999998
# Bad ttfex ampl: 108
# Bad ttfex amplnxt: 108
# Bad ttfex fltpos: 108
# Bad ttfex fltpos_ps: 108
# Bad ttfex fltposfwhm: 108
# Bad ttfex proj_ref: 108
# Bad ttfex proj_sig: 108
# Bad ttfex refampl: 108
# 3308.4325369999997
# Bad ttfex ampl: 109
# Bad ttfex amplnxt: 109
# Bad ttfex fltpos: 109
# Bad ttfex fltpos_ps: 109
# Bad ttfex fltposfwhm: 109
# Bad ttfex proj_ref: 109
# Bad ttfex proj_sig: 109
# Bad ttfex refampl: 109
# 3308.439204
# 3308.312531
# Bad ttfex ampl: 111
# Bad ttfex amplnxt: 111
# Bad ttfex fltpos: 111
# Bad ttfex fltpos_ps: 111
# Bad ttfex fltposfwhm: 111
# Bad ttfex proj_ref: 111
# Bad ttfex proj_sig: 111
# Bad ttfex refampl: 111
# 3308.4592049999997
# Bad ttfex ampl: 112
# Bad ttfex amplnxt: 112
# Bad ttfex fltpos: 112
# Bad ttfex fltpos_ps: 112
# Bad ttfex fltposfwhm: 112
# Bad ttfex proj_ref: 112
# Bad ttfex proj_sig: 112
# Bad ttfex refampl: 112
# 3308.445871
# Bad ttfex ampl: 113
# Bad ttfex amplnxt: 113
# Bad ttfex fltpos: 113
# Bad ttfex fltpos_ps: 113
# Bad ttfex fltposfwhm: 113
# Bad ttfex proj_ref: 113
# Bad ttfex proj_sig: 113
# Bad ttfex refampl: 113
# 3308.4925399999997
# Bad ttfex ampl: 114
# Bad ttfex amplnxt: 114
# Bad ttfex fltpos: 114
# Bad ttfex fltpos_ps: 114
# Bad ttfex fltposfwhm: 114
# Bad ttfex proj_ref: 114
# Bad ttfex proj_sig: 114
# Bad ttfex refampl: 114
# 3308.4658719999998
# Bad ttfex ampl: 115
# Bad ttfex amplnxt: 115
# Bad ttfex fltpos: 115
# Bad ttfex fltpos_ps: 115
# Bad ttfex fltposfwhm: 115
# Bad ttfex proj_ref: 115
# Bad ttfex proj_sig: 115
# Bad ttfex refampl: 115
# 3308.4058689999997
# Bad ttfex ampl: 116
# Bad ttfex amplnxt: 116
# Bad ttfex fltpos: 116
# Bad ttfex fltpos_ps: 116
# Bad ttfex fltposfwhm: 116
# Bad ttfex proj_ref: 116
# Bad ttfex proj_sig: 116
# Bad ttfex refampl: 116
# 3308.4658719999998
# 3308.4858729999996
# Bad ttfex ampl: 118
# Bad ttfex amplnxt: 118
# Bad ttfex fltpos: 118
# Bad ttfex fltpos_ps: 118
# Bad ttfex fltposfwhm: 118
# Bad ttfex proj_ref: 118
# Bad ttfex proj_sig: 118
# Bad ttfex refampl: 118
# 3308.4658719999998
# 3308.419203
# Bad ttfex ampl: 120
# Bad ttfex amplnxt: 120
# Bad ttfex fltpos: 120
# Bad ttfex fltpos_ps: 120
# Bad ttfex fltposfwhm: 120
# Bad ttfex proj_ref: 120
# Bad ttfex proj_sig: 120
# Bad ttfex refampl: 120
# 3308.3592
# Bad ttfex ampl: 121
# Bad ttfex amplnxt: 121
# Bad ttfex fltpos: 121
# Bad ttfex fltpos_ps: 121
# Bad ttfex fltposfwhm: 121
# Bad ttfex proj_ref: 121
# Bad ttfex proj_sig: 121
# Bad ttfex refampl: 121
# 3308.399202
# Bad ttfex ampl: 122
# Bad ttfex amplnxt: 122
# Bad ttfex fltpos: 122
# Bad ttfex fltpos_ps: 122
# Bad ttfex fltposfwhm: 122
# Bad ttfex proj_ref: 122
# Bad ttfex proj_sig: 122
# Bad ttfex refampl: 122
# 3308.472539
# Bad ttfex ampl: 123
# Bad ttfex amplnxt: 123
# Bad ttfex fltpos: 123
# Bad ttfex fltpos_ps: 123
# Bad ttfex fltposfwhm: 123
# Bad ttfex proj_ref: 123
# Bad ttfex proj_sig: 123
# Bad ttfex refampl: 123
# 3308.4592049999997
# Bad ttfex ampl: 124
# Bad ttfex amplnxt: 124
# Bad ttfex fltpos: 124
# Bad ttfex fltpos_ps: 124
# Bad ttfex fltposfwhm: 124
# Bad ttfex proj_ref: 124
# Bad ttfex proj_sig: 124
# Bad ttfex refampl: 124
# 3308.472539
# Bad ttfex ampl: 125
# Bad ttfex amplnxt: 125
# Bad ttfex fltpos: 125
# Bad ttfex fltpos_ps: 125
# Bad ttfex fltposfwhm: 125
# Bad ttfex proj_ref: 125
# Bad ttfex proj_sig: 125
# Bad ttfex refampl: 125
# 3308.499207
# Bad ttfex ampl: 126
# Bad ttfex amplnxt: 126
# Bad ttfex fltpos: 126
# Bad ttfex fltpos_ps: 126
# Bad ttfex fltposfwhm: 126
# Bad ttfex proj_ref: 126
# Bad ttfex proj_sig: 126
# Bad ttfex refampl: 126
# 3308.539209
# Bad ttfex ampl: 127
# Bad ttfex amplnxt: 127
# Bad ttfex fltpos: 127
# Bad ttfex fltpos_ps: 127
# Bad ttfex fltposfwhm: 127
# Bad ttfex proj_ref: 127
# Bad ttfex proj_sig: 127
# Bad ttfex refampl: 127
# 3308.452538
# Bad ttfex ampl: 128
# Bad ttfex amplnxt: 128
# Bad ttfex fltpos: 128
# Bad ttfex fltpos_ps: 128
# Bad ttfex fltposfwhm: 128
# Bad ttfex proj_ref: 128
# Bad ttfex proj_sig: 128
# Bad ttfex refampl: 128
# 3308.392535
# Bad ttfex ampl: 129
# Bad ttfex amplnxt: 129
# Bad ttfex fltpos: 129
# Bad ttfex fltpos_ps: 129
# Bad ttfex fltposfwhm: 129
# Bad ttfex proj_ref: 129
# Bad ttfex proj_sig: 129
# Bad ttfex refampl: 129
# 3308.539209
# Bad ttfex ampl: 130
# Bad ttfex amplnxt: 130
# Bad ttfex fltpos: 130
# Bad ttfex fltpos_ps: 130
# Bad ttfex fltposfwhm: 130
# Bad ttfex proj_ref: 130
# Bad ttfex proj_sig: 130
# Bad ttfex refampl: 130
# 3308.525875
# 3308.3592
# Bad ttfex ampl: 132
# Bad ttfex amplnxt: 132
# Bad ttfex fltpos: 132
# Bad ttfex fltpos_ps: 132
# Bad ttfex fltposfwhm: 132
# Bad ttfex proj_ref: 132
# Bad ttfex proj_sig: 132
# Bad ttfex refampl: 132
# 3308.439204
# 3308.4658719999998
# Bad ttfex ampl: 134
# Bad ttfex amplnxt: 134
# Bad ttfex fltpos: 134
# Bad ttfex fltpos_ps: 134
# Bad ttfex fltposfwhm: 134
# Bad ttfex proj_ref: 134
# Bad ttfex proj_sig: 134
# Bad ttfex refampl: 134
# 3308.4325369999997
# Bad ttfex ampl: 135
# Bad ttfex amplnxt: 135
# Bad ttfex fltpos: 135
# Bad ttfex fltpos_ps: 135
# Bad ttfex fltposfwhm: 135
# Bad ttfex proj_ref: 135
# Bad ttfex proj_sig: 135
# Bad ttfex refampl: 135
# 3308.4325369999997
# 3308.4658719999998
# Bad ttfex ampl: 137
# Bad ttfex amplnxt: 137
# Bad ttfex fltpos: 137
# Bad ttfex fltpos_ps: 137
# Bad ttfex fltposfwhm: 137
# Bad ttfex proj_ref: 137
# Bad ttfex proj_sig: 137
# Bad ttfex refampl: 137
# 3308.392535
# 3308.3592
# Bad ttfex ampl: 139
# Bad ttfex amplnxt: 139
# Bad ttfex fltpos: 139
# Bad ttfex fltpos_ps: 139
# Bad ttfex fltposfwhm: 139
# Bad ttfex proj_ref: 139
# Bad ttfex proj_sig: 139
# Bad ttfex refampl: 139
# 3308.55921
# 3308.419203
# Bad ttfex ampl: 141
# Bad ttfex amplnxt: 141
# Bad ttfex fltpos: 141
# Bad ttfex fltpos_ps: 141
# Bad ttfex fltposfwhm: 141
# Bad ttfex proj_ref: 141
# Bad ttfex proj_sig: 141
# Bad ttfex refampl: 141
# 3308.445871
# Bad ttfex ampl: 142
# Bad ttfex amplnxt: 142
# Bad ttfex fltpos: 142
# Bad ttfex fltpos_ps: 142
# Bad ttfex fltposfwhm: 142
# Bad ttfex proj_ref: 142
# Bad ttfex proj_sig: 142
# Bad ttfex refampl: 142
# 3308.3725339999996
# Bad ttfex ampl: 143
# Bad ttfex amplnxt: 143
# Bad ttfex fltpos: 143
# Bad ttfex fltpos_ps: 143
# Bad ttfex fltposfwhm: 143
# Bad ttfex proj_ref: 143
# Bad ttfex proj_sig: 143
# Bad ttfex refampl: 143
# 3308.3458659999997
# Bad ttfex ampl: 144
# Bad ttfex amplnxt: 144
# Bad ttfex fltpos: 144
# Bad ttfex fltpos_ps: 144
# Bad ttfex fltposfwhm: 144
# Bad ttfex proj_ref: 144
# Bad ttfex proj_sig: 144
# Bad ttfex refampl: 144
# 3308.42587
# 3308.439204
# Bad ttfex ampl: 146
# Bad ttfex amplnxt: 146
# Bad ttfex fltpos: 146
# Bad ttfex fltpos_ps: 146
# Bad ttfex fltposfwhm: 146
# Bad ttfex proj_ref: 146
# Bad ttfex proj_sig: 146
# Bad ttfex refampl: 146
# 3308.512541
# Bad ttfex ampl: 147
# Bad ttfex amplnxt: 147
# Bad ttfex fltpos: 147
# Bad ttfex fltpos_ps: 147
# Bad ttfex fltposfwhm: 147
# Bad ttfex proj_ref: 147
# Bad ttfex proj_sig: 147
# Bad ttfex refampl: 147
# 3308.4925399999997
# Bad ttfex ampl: 148
# Bad ttfex amplnxt: 148
# Bad ttfex fltpos: 148
# Bad ttfex fltpos_ps: 148
# Bad ttfex fltposfwhm: 148
# Bad ttfex proj_ref: 148
# Bad ttfex proj_sig: 148
# Bad ttfex refampl: 148
# 3308.439204
# Bad ttfex ampl: 149
# Bad ttfex amplnxt: 149
# Bad ttfex fltpos: 149
# Bad ttfex fltpos_ps: 149
# Bad ttfex fltposfwhm: 149
# Bad ttfex proj_ref: 149
# Bad ttfex proj_sig: 149
# Bad ttfex refampl: 149
# Event number: 150, Valid shots: 102
# 3308.332532
# Bad ttfex ampl: 150
# Bad ttfex amplnxt: 150
# Bad ttfex fltpos: 150
# Bad ttfex fltpos_ps: 150
# Bad ttfex fltposfwhm: 150
# Bad ttfex proj_ref: 150
# Bad ttfex proj_sig: 150
# Bad ttfex refampl: 150
# 3308.325865
# Bad ttfex ampl: 151
# Bad ttfex amplnxt: 151
# Bad ttfex fltpos: 151
# Bad ttfex fltpos_ps: 151
# Bad ttfex fltposfwhm: 151
# Bad ttfex proj_ref: 151
# Bad ttfex proj_sig: 151
# Bad ttfex refampl: 151
# 3308.4325369999997
# Bad ttfex ampl: 152
# Bad ttfex amplnxt: 152
# Bad ttfex fltpos: 152
# Bad ttfex fltpos_ps: 152
# Bad ttfex fltposfwhm: 152
# Bad ttfex proj_ref: 152
# Bad ttfex proj_sig: 152
# Bad ttfex refampl: 152
# 3308.4325369999997
# Bad ttfex ampl: 153
# Bad ttfex amplnxt: 153
# Bad ttfex fltpos: 153
# Bad ttfex fltpos_ps: 153
# Bad ttfex fltposfwhm: 153
# Bad ttfex proj_ref: 153
# Bad ttfex proj_sig: 153
# Bad ttfex refampl: 153
# 3308.452538
# Bad ttfex ampl: 154
# Bad ttfex amplnxt: 154
# Bad ttfex fltpos: 154
# Bad ttfex fltpos_ps: 154
# Bad ttfex fltposfwhm: 154
# Bad ttfex proj_ref: 154
# Bad ttfex proj_sig: 154
# Bad ttfex refampl: 154
# 3308.4858729999996
# 3308.5192079999997
# Bad ttfex ampl: 156
# Bad ttfex amplnxt: 156
# Bad ttfex fltpos: 156
# Bad ttfex fltpos_ps: 156
# Bad ttfex fltposfwhm: 156
# Bad ttfex proj_ref: 156
# Bad ttfex proj_sig: 156
# Bad ttfex refampl: 156
# 3308.512541
# 3308.419203
# Bad ttfex ampl: 158
# Bad ttfex amplnxt: 158
# Bad ttfex fltpos: 158
# Bad ttfex fltpos_ps: 158
# Bad ttfex fltposfwhm: 158
# Bad ttfex proj_ref: 158
# Bad ttfex proj_sig: 158
# Bad ttfex refampl: 158
# 3308.445871
# Bad ttfex ampl: 159
# Bad ttfex amplnxt: 159
# Bad ttfex fltpos: 159
# Bad ttfex fltpos_ps: 159
# Bad ttfex fltposfwhm: 159
# Bad ttfex proj_ref: 159
# Bad ttfex proj_sig: 159
# Bad ttfex refampl: 159
# 3308.3458659999997
# Bad ttfex ampl: 160
# Bad ttfex amplnxt: 160
# Bad ttfex fltpos: 160
# Bad ttfex fltpos_ps: 160
# Bad ttfex fltposfwhm: 160
# Bad ttfex proj_ref: 160
# Bad ttfex proj_sig: 160
# Bad ttfex refampl: 160
# 3308.479206
# Bad ttfex ampl: 161
# Bad ttfex amplnxt: 161
# Bad ttfex fltpos: 161
# Bad ttfex fltpos_ps: 161
# Bad ttfex fltposfwhm: 161
# Bad ttfex proj_ref: 161
# Bad ttfex proj_sig: 161
# Bad ttfex refampl: 161
# 3308.512541
# Bad ttfex ampl: 162
# Bad ttfex amplnxt: 162
# Bad ttfex fltpos: 162
# Bad ttfex fltpos_ps: 162
# Bad ttfex fltposfwhm: 162
# Bad ttfex proj_ref: 162
# Bad ttfex proj_sig: 162
# Bad ttfex refampl: 162
# 3308.472539
# 3308.452538
# Bad ttfex ampl: 164
# Bad ttfex amplnxt: 164
# Bad ttfex fltpos: 164
# Bad ttfex fltpos_ps: 164
# Bad ttfex fltposfwhm: 164
# Bad ttfex proj_ref: 164
# Bad ttfex proj_sig: 164
# Bad ttfex refampl: 164
# 3308.4325369999997
# 3308.392535
# 3308.325865
# Bad ttfex ampl: 167
# Bad ttfex amplnxt: 167
# Bad ttfex fltpos: 167
# Bad ttfex fltpos_ps: 167
# Bad ttfex fltposfwhm: 167
# Bad ttfex proj_ref: 167
# Bad ttfex proj_sig: 167
# Bad ttfex refampl: 167
# 3308.42587
# Bad ttfex ampl: 168
# Bad ttfex amplnxt: 168
# Bad ttfex fltpos: 168
# Bad ttfex fltpos_ps: 168
# Bad ttfex fltposfwhm: 168
# Bad ttfex proj_ref: 168
# Bad ttfex proj_sig: 168
# Bad ttfex refampl: 168
# 3308.4925399999997
# Bad ttfex ampl: 169
# Bad ttfex amplnxt: 169
# Bad ttfex fltpos: 169
# Bad ttfex fltpos_ps: 169
# Bad ttfex fltposfwhm: 169
# Bad ttfex proj_ref: 169
# Bad ttfex proj_sig: 169
# Bad ttfex refampl: 169
# 3308.4325369999997
# Bad ttfex ampl: 170
# Bad ttfex amplnxt: 170
# Bad ttfex fltpos: 170
# Bad ttfex fltpos_ps: 170
# Bad ttfex fltposfwhm: 170
# Bad ttfex proj_ref: 170
# Bad ttfex proj_sig: 170
# Bad ttfex refampl: 170
# 3308.3525329999998
# Bad ttfex ampl: 171
# Bad ttfex amplnxt: 171
# Bad ttfex fltpos: 171
# Bad ttfex fltpos_ps: 171
# Bad ttfex fltposfwhm: 171
# Bad ttfex proj_ref: 171
# Bad ttfex proj_sig: 171
# Bad ttfex refampl: 171
# 3308.4325369999997
# Bad ttfex ampl: 172
# Bad ttfex amplnxt: 172
# Bad ttfex fltpos: 172
# Bad ttfex fltpos_ps: 172
# Bad ttfex fltposfwhm: 172
# Bad ttfex proj_ref: 172
# Bad ttfex proj_sig: 172
# Bad ttfex refampl: 172
# 3308.399202
# Bad ttfex ampl: 173
# Bad ttfex amplnxt: 173
# Bad ttfex fltpos: 173
# Bad ttfex fltpos_ps: 173
# Bad ttfex fltposfwhm: 173
# Bad ttfex proj_ref: 173
# Bad ttfex proj_sig: 173
# Bad ttfex refampl: 173
# 3308.4858729999996
# Bad ttfex ampl: 174
# Bad ttfex amplnxt: 174
# Bad ttfex fltpos: 174
# Bad ttfex fltpos_ps: 174
# Bad ttfex fltposfwhm: 174
# Bad ttfex proj_ref: 174
# Bad ttfex proj_sig: 174
# Bad ttfex refampl: 174
# 3308.539209
# Bad ttfex ampl: 175
# Bad ttfex amplnxt: 175
# Bad ttfex fltpos: 175
# Bad ttfex fltpos_ps: 175
# Bad ttfex fltposfwhm: 175
# Bad ttfex proj_ref: 175
# Bad ttfex proj_sig: 175
# Bad ttfex refampl: 175
# 3308.272529
# Bad ttfex ampl: 176
# Bad ttfex amplnxt: 176
# Bad ttfex fltpos: 176
# Bad ttfex fltpos_ps: 176
# Bad ttfex fltposfwhm: 176
# Bad ttfex proj_ref: 176
# Bad ttfex proj_sig: 176
# Bad ttfex refampl: 176
# 3308.4058689999997
# Bad ttfex ampl: 177
# Bad ttfex amplnxt: 177
# Bad ttfex fltpos: 177
# Bad ttfex fltpos_ps: 177
# Bad ttfex fltposfwhm: 177
# Bad ttfex proj_ref: 177
# Bad ttfex proj_sig: 177
# Bad ttfex refampl: 177
# 3308.399202
# Bad ttfex ampl: 178
# Bad ttfex amplnxt: 178
# Bad ttfex fltpos: 178
# Bad ttfex fltpos_ps: 178
# Bad ttfex fltposfwhm: 178
# Bad ttfex proj_ref: 178
# Bad ttfex proj_sig: 178
# Bad ttfex refampl: 178
# 3308.3792009999997
# Bad ttfex ampl: 179
# Bad ttfex amplnxt: 179
# Bad ttfex fltpos: 179
# Bad ttfex fltpos_ps: 179
# Bad ttfex fltposfwhm: 179
# Bad ttfex proj_ref: 179
# Bad ttfex proj_sig: 179
# Bad ttfex refampl: 179
# 3308.419203
# Bad ttfex ampl: 180
# Bad ttfex amplnxt: 180
# Bad ttfex fltpos: 180
# Bad ttfex fltpos_ps: 180
# Bad ttfex fltposfwhm: 180
# Bad ttfex proj_ref: 180
# Bad ttfex proj_sig: 180
# Bad ttfex refampl: 180
# 3308.42587
# Bad ttfex ampl: 181
# Bad ttfex amplnxt: 181
# Bad ttfex fltpos: 181
# Bad ttfex fltpos_ps: 181
# Bad ttfex fltposfwhm: 181
# Bad ttfex proj_ref: 181
# Bad ttfex proj_sig: 181
# Bad ttfex refampl: 181
# 3308.3792009999997
# Bad ttfex ampl: 182
# Bad ttfex amplnxt: 182
# Bad ttfex fltpos: 182
# Bad ttfex fltpos_ps: 182
# Bad ttfex fltposfwhm: 182
# Bad ttfex proj_ref: 182
# Bad ttfex proj_sig: 182
# Bad ttfex refampl: 182
# 3308.325865
# Bad ttfex ampl: 183
# Bad ttfex amplnxt: 183
# Bad ttfex fltpos: 183
# Bad ttfex fltpos_ps: 183
# Bad ttfex fltposfwhm: 183
# Bad ttfex proj_ref: 183
# Bad ttfex proj_sig: 183
# Bad ttfex refampl: 183
# 3308.5458759999997
# Bad ttfex ampl: 184
# Bad ttfex amplnxt: 184
# Bad ttfex fltpos: 184
# Bad ttfex fltpos_ps: 184
# Bad ttfex fltposfwhm: 184
# Bad ttfex proj_ref: 184
# Bad ttfex proj_sig: 184
# Bad ttfex refampl: 184
# 3308.4658719999998
# Bad ttfex ampl: 185
# Bad ttfex amplnxt: 185
# Bad ttfex fltpos: 185
# Bad ttfex fltpos_ps: 185
# Bad ttfex fltposfwhm: 185
# Bad ttfex proj_ref: 185
# Bad ttfex proj_sig: 185
# Bad ttfex refampl: 185
# 3308.4325369999997
# Bad ttfex ampl: 186
# Bad ttfex amplnxt: 186
# Bad ttfex fltpos: 186
# Bad ttfex fltpos_ps: 186
# Bad ttfex fltposfwhm: 186
# Bad ttfex proj_ref: 186
# Bad ttfex proj_sig: 186
# Bad ttfex refampl: 186
# 3308.419203
# Bad ttfex ampl: 187
# Bad ttfex amplnxt: 187
# Bad ttfex fltpos: 187
# Bad ttfex fltpos_ps: 187
# Bad ttfex fltposfwhm: 187
# Bad ttfex proj_ref: 187
# Bad ttfex proj_sig: 187
# Bad ttfex refampl: 187
# 3308.305864
# Bad ttfex ampl: 188
# Bad ttfex amplnxt: 188
# Bad ttfex fltpos: 188
# Bad ttfex fltpos_ps: 188
# Bad ttfex fltposfwhm: 188
# Bad ttfex proj_ref: 188
# Bad ttfex proj_sig: 188
# Bad ttfex refampl: 188
# 3308.4325369999997
# Bad ttfex ampl: 189
# Bad ttfex amplnxt: 189
# Bad ttfex fltpos: 189
# Bad ttfex fltpos_ps: 189
# Bad ttfex fltposfwhm: 189
# Bad ttfex proj_ref: 189
# Bad ttfex proj_sig: 189
# Bad ttfex refampl: 189
# 3308.4325369999997
# Bad ttfex ampl: 190
# Bad ttfex amplnxt: 190
# Bad ttfex fltpos: 190
# Bad ttfex fltpos_ps: 190
# Bad ttfex fltposfwhm: 190
# Bad ttfex proj_ref: 190
# Bad ttfex proj_sig: 190
# Bad ttfex refampl: 190
# 3308.4325369999997
# Bad ttfex ampl: 191
# Bad ttfex amplnxt: 191
# Bad ttfex fltpos: 191
# Bad ttfex fltpos_ps: 191
# Bad ttfex fltposfwhm: 191
# Bad ttfex proj_ref: 191
# Bad ttfex proj_sig: 191
# Bad ttfex refampl: 191
# 3308.4658719999998
# Bad ttfex ampl: 192
# Bad ttfex amplnxt: 192
# Bad ttfex fltpos: 192
# Bad ttfex fltpos_ps: 192
# Bad ttfex fltposfwhm: 192
# Bad ttfex proj_ref: 192
# Bad ttfex proj_sig: 192
# Bad ttfex refampl: 192
# 3308.3525329999998
# Bad ttfex ampl: 193
# Bad ttfex amplnxt: 193
# Bad ttfex fltpos: 193
# Bad ttfex fltpos_ps: 193
# Bad ttfex fltposfwhm: 193
# Bad ttfex proj_ref: 193
# Bad ttfex proj_sig: 193
# Bad ttfex refampl: 193
# 3308.479206
# Bad ttfex ampl: 194
# Bad ttfex amplnxt: 194
# Bad ttfex fltpos: 194
# Bad ttfex fltpos_ps: 194
# Bad ttfex fltposfwhm: 194
# Bad ttfex proj_ref: 194
# Bad ttfex proj_sig: 194
# Bad ttfex refampl: 194
# 3308.42587
# Bad ttfex ampl: 195
# Bad ttfex amplnxt: 195
# Bad ttfex fltpos: 195
# Bad ttfex fltpos_ps: 195
# Bad ttfex fltposfwhm: 195
# Bad ttfex proj_ref: 195
# Bad ttfex proj_sig: 195
# Bad ttfex refampl: 195
# 3308.479206
# Bad ttfex ampl: 196
# Bad ttfex amplnxt: 196
# Bad ttfex fltpos: 196
# Bad ttfex fltpos_ps: 196
# Bad ttfex fltposfwhm: 196
# Bad ttfex proj_ref: 196
# Bad ttfex proj_sig: 196
# Bad ttfex refampl: 196
# 3308.525875
# Bad ttfex ampl: 197
# Bad ttfex amplnxt: 197
# Bad ttfex fltpos: 197
# Bad ttfex fltpos_ps: 197
# Bad ttfex fltposfwhm: 197
# Bad ttfex proj_ref: 197
# Bad ttfex proj_sig: 197
# Bad ttfex refampl: 197
# 3308.42587
# Bad ttfex ampl: 198
# Bad ttfex amplnxt: 198
# Bad ttfex fltpos: 198
# Bad ttfex fltpos_ps: 198
# Bad ttfex fltposfwhm: 198
# Bad ttfex proj_ref: 198
# Bad ttfex proj_sig: 198
# Bad ttfex refampl: 198
# 3308.419203
# Bad ttfex ampl: 199
# Bad ttfex amplnxt: 199
# Bad ttfex fltpos: 199
# Bad ttfex fltpos_ps: 199
# Bad ttfex fltposfwhm: 199
# Bad ttfex proj_ref: 199
# Bad ttfex proj_sig: 199
# Bad ttfex refampl: 199
# Event number: 200, Valid shots: 152
# 3308.365867
# Bad ttfex ampl: 200
# Bad ttfex amplnxt: 200
# Bad ttfex fltpos: 200
# Bad ttfex fltpos_ps: 200
# Bad ttfex fltposfwhm: 200
# Bad ttfex proj_ref: 200
# Bad ttfex proj_sig: 200
# Bad ttfex refampl: 200
# 3308.439204
# Bad ttfex ampl: 201
# Bad ttfex amplnxt: 201
# Bad ttfex fltpos: 201
# Bad ttfex fltpos_ps: 201
# Bad ttfex fltposfwhm: 201
# Bad ttfex proj_ref: 201
# Bad ttfex proj_sig: 201
# Bad ttfex refampl: 201
# 3308.452538
# Bad ttfex ampl: 202
# Bad ttfex amplnxt: 202
# Bad ttfex fltpos: 202
# Bad ttfex fltpos_ps: 202
# Bad ttfex fltposfwhm: 202
# Bad ttfex proj_ref: 202
# Bad ttfex proj_sig: 202
# Bad ttfex refampl: 202
# 3308.445871
# Bad ttfex ampl: 203
# Bad ttfex amplnxt: 203
# Bad ttfex fltpos: 203
# Bad ttfex fltpos_ps: 203
# Bad ttfex fltposfwhm: 203
# Bad ttfex proj_ref: 203
# Bad ttfex proj_sig: 203
# Bad ttfex refampl: 203
# 3308.332532
# Bad ttfex ampl: 204
# Bad ttfex amplnxt: 204
# Bad ttfex fltpos: 204
# Bad ttfex fltpos_ps: 204
# Bad ttfex fltposfwhm: 204
# Bad ttfex proj_ref: 204
# Bad ttfex proj_sig: 204
# Bad ttfex refampl: 204
# 3308.472539
# Bad ttfex ampl: 205
# Bad ttfex amplnxt: 205
# Bad ttfex fltpos: 205
# Bad ttfex fltpos_ps: 205
# Bad ttfex fltposfwhm: 205
# Bad ttfex proj_ref: 205
# Bad ttfex proj_sig: 205
# Bad ttfex refampl: 205
# 3308.399202
# Bad ttfex ampl: 206
# Bad ttfex amplnxt: 206
# Bad ttfex fltpos: 206
# Bad ttfex fltpos_ps: 206
# Bad ttfex fltposfwhm: 206
# Bad ttfex proj_ref: 206
# Bad ttfex proj_sig: 206
# Bad ttfex refampl: 206
# 3308.445871
# Bad ttfex ampl: 207
# Bad ttfex amplnxt: 207
# Bad ttfex fltpos: 207
# Bad ttfex fltpos_ps: 207
# Bad ttfex fltposfwhm: 207
# Bad ttfex proj_ref: 207
# Bad ttfex proj_sig: 207
# Bad ttfex refampl: 207
# 3308.479206
# Bad ttfex ampl: 208
# Bad ttfex amplnxt: 208
# Bad ttfex fltpos: 208
# Bad ttfex fltpos_ps: 208
# Bad ttfex fltposfwhm: 208
# Bad ttfex proj_ref: 208
# Bad ttfex proj_sig: 208
# Bad ttfex refampl: 208
# 3308.3725339999996
# Bad ttfex ampl: 209
# Bad ttfex amplnxt: 209
# Bad ttfex fltpos: 209
# Bad ttfex fltpos_ps: 209
# Bad ttfex fltposfwhm: 209
# Bad ttfex proj_ref: 209
# Bad ttfex proj_sig: 209
# Bad ttfex refampl: 209
# 3308.412536
# Bad ttfex ampl: 210
# Bad ttfex amplnxt: 210
# Bad ttfex fltpos: 210
# Bad ttfex fltpos_ps: 210
# Bad ttfex fltposfwhm: 210
# Bad ttfex proj_ref: 210
# Bad ttfex proj_sig: 210
# Bad ttfex refampl: 210
# 3308.4658719999998
# 3308.472539
# 3308.565877
# Bad ttfex ampl: 213
# Bad ttfex amplnxt: 213
# Bad ttfex fltpos: 213
# Bad ttfex fltpos_ps: 213
# Bad ttfex fltposfwhm: 213
# Bad ttfex proj_ref: 213
# Bad ttfex proj_sig: 213
# Bad ttfex refampl: 213
# 3308.4058689999997
# Bad ttfex ampl: 214
# Bad ttfex amplnxt: 214
# Bad ttfex fltpos: 214
# Bad ttfex fltpos_ps: 214
# Bad ttfex fltposfwhm: 214
# Bad ttfex proj_ref: 214
# Bad ttfex proj_sig: 214
# Bad ttfex refampl: 214
# 3308.419203
# Bad ttfex ampl: 215
# Bad ttfex amplnxt: 215
# Bad ttfex fltpos: 215
# Bad ttfex fltpos_ps: 215
# Bad ttfex fltposfwhm: 215
# Bad ttfex proj_ref: 215
# Bad ttfex proj_sig: 215
# Bad ttfex refampl: 215
# 3308.525875
# Bad ttfex ampl: 216
# Bad ttfex amplnxt: 216
# Bad ttfex fltpos: 216
# Bad ttfex fltpos_ps: 216
# Bad ttfex fltposfwhm: 216
# Bad ttfex proj_ref: 216
# Bad ttfex proj_sig: 216
# Bad ttfex refampl: 216
# 3308.445871
# Bad ttfex ampl: 217
# Bad ttfex amplnxt: 217
# Bad ttfex fltpos: 217
# Bad ttfex fltpos_ps: 217
# Bad ttfex fltposfwhm: 217
# Bad ttfex proj_ref: 217
# Bad ttfex proj_sig: 217
# Bad ttfex refampl: 217
# 3308.472539
# Bad ttfex ampl: 218
# Bad ttfex amplnxt: 218
# Bad ttfex fltpos: 218
# Bad ttfex fltpos_ps: 218
# Bad ttfex fltposfwhm: 218
# Bad ttfex proj_ref: 218
# Bad ttfex proj_sig: 218
# Bad ttfex refampl: 218
# 3308.499207
# Bad ttfex ampl: 219
# Bad ttfex amplnxt: 219
# Bad ttfex fltpos: 219
# Bad ttfex fltpos_ps: 219
# Bad ttfex fltposfwhm: 219
# Bad ttfex proj_ref: 219
# Bad ttfex proj_sig: 219
# Bad ttfex refampl: 219
# 3308.365867
# 3308.445871
# 3308.452538
# Bad ttfex ampl: 222
# Bad ttfex amplnxt: 222
# Bad ttfex fltpos: 222
# Bad ttfex fltpos_ps: 222
# Bad ttfex fltposfwhm: 222
# Bad ttfex proj_ref: 222
# Bad ttfex proj_sig: 222
# Bad ttfex refampl: 222
# 3308.539209
# Bad ttfex ampl: 223
# Bad ttfex amplnxt: 223
# Bad ttfex fltpos: 223
# Bad ttfex fltpos_ps: 223
# Bad ttfex fltposfwhm: 223
# Bad ttfex proj_ref: 223
# Bad ttfex proj_sig: 223
# Bad ttfex refampl: 223
# 3308.525875
# Bad ttfex ampl: 224
# Bad ttfex amplnxt: 224
# Bad ttfex fltpos: 224
# Bad ttfex fltpos_ps: 224
# Bad ttfex fltposfwhm: 224
# Bad ttfex proj_ref: 224
# Bad ttfex proj_sig: 224
# Bad ttfex refampl: 224
# 3308.539209
# Bad ttfex ampl: 225
# Bad ttfex amplnxt: 225
# Bad ttfex fltpos: 225
# Bad ttfex fltpos_ps: 225
# Bad ttfex fltposfwhm: 225
# Bad ttfex proj_ref: 225
# Bad ttfex proj_sig: 225
# Bad ttfex refampl: 225
# 3308.385868
# Bad ttfex ampl: 226
# Bad ttfex amplnxt: 226
# Bad ttfex fltpos: 226
# Bad ttfex fltpos_ps: 226
# Bad ttfex fltposfwhm: 226
# Bad ttfex proj_ref: 226
# Bad ttfex proj_sig: 226
# Bad ttfex refampl: 226
# 3308.3458659999997
# 3308.4925399999997
# Bad ttfex ampl: 228
# Bad ttfex amplnxt: 228
# Bad ttfex fltpos: 228
# Bad ttfex fltpos_ps: 228
# Bad ttfex fltposfwhm: 228
# Bad ttfex proj_ref: 228
# Bad ttfex proj_sig: 228
# Bad ttfex refampl: 228
# 3308.472539
# 3308.4858729999996
# Bad ttfex ampl: 230
# Bad ttfex amplnxt: 230
# Bad ttfex fltpos: 230
# Bad ttfex fltpos_ps: 230
# Bad ttfex fltposfwhm: 230
# Bad ttfex proj_ref: 230
# Bad ttfex proj_sig: 230
# Bad ttfex refampl: 230
# 3308.5192079999997
# Bad ttfex ampl: 231
# Bad ttfex amplnxt: 231
# Bad ttfex fltpos: 231
# Bad ttfex fltpos_ps: 231
# Bad ttfex fltposfwhm: 231
# Bad ttfex proj_ref: 231
# Bad ttfex proj_sig: 231
# Bad ttfex refampl: 231
# 3308.42587
# Bad ttfex ampl: 232
# Bad ttfex amplnxt: 232
# Bad ttfex fltpos: 232
# Bad ttfex fltpos_ps: 232
# Bad ttfex fltposfwhm: 232
# Bad ttfex proj_ref: 232
# Bad ttfex proj_sig: 232
# Bad ttfex refampl: 232
# 3308.472539
# Bad ttfex ampl: 233
# Bad ttfex amplnxt: 233
# Bad ttfex fltpos: 233
# Bad ttfex fltpos_ps: 233
# Bad ttfex fltposfwhm: 233
# Bad ttfex proj_ref: 233
# Bad ttfex proj_sig: 233
# Bad ttfex refampl: 233
# 3308.479206
# Bad ttfex ampl: 234
# Bad ttfex amplnxt: 234
# Bad ttfex fltpos: 234
# Bad ttfex fltpos_ps: 234
# Bad ttfex fltposfwhm: 234
# Bad ttfex proj_ref: 234
# Bad ttfex proj_sig: 234
# Bad ttfex refampl: 234
# 3308.3725339999996
# Bad ttfex ampl: 235
# Bad ttfex amplnxt: 235
# Bad ttfex fltpos: 235
# Bad ttfex fltpos_ps: 235
# Bad ttfex fltposfwhm: 235
# Bad ttfex proj_ref: 235
# Bad ttfex proj_sig: 235
# Bad ttfex refampl: 235
# 3308.4858729999996
# Bad ttfex ampl: 236
# Bad ttfex amplnxt: 236
# Bad ttfex fltpos: 236
# Bad ttfex fltpos_ps: 236
# Bad ttfex fltposfwhm: 236
# Bad ttfex proj_ref: 236
# Bad ttfex proj_sig: 236
# Bad ttfex refampl: 236
# 3308.439204
# Bad ttfex ampl: 237
# Bad ttfex amplnxt: 237
# Bad ttfex fltpos: 237
# Bad ttfex fltpos_ps: 237
# Bad ttfex fltposfwhm: 237
# Bad ttfex proj_ref: 237
# Bad ttfex proj_sig: 237
# Bad ttfex refampl: 237
# 3308.419203
# Bad ttfex ampl: 238
# Bad ttfex amplnxt: 238
# Bad ttfex fltpos: 238
# Bad ttfex fltpos_ps: 238
# Bad ttfex fltposfwhm: 238
# Bad ttfex proj_ref: 238
# Bad ttfex proj_sig: 238
# Bad ttfex refampl: 238
# 3308.445871
# Bad ttfex ampl: 239
# Bad ttfex amplnxt: 239
# Bad ttfex fltpos: 239
# Bad ttfex fltpos_ps: 239
# Bad ttfex fltposfwhm: 239
# Bad ttfex proj_ref: 239
# Bad ttfex proj_sig: 239
# Bad ttfex refampl: 239
# 3308.4058689999997
# Bad ttfex ampl: 240
# Bad ttfex amplnxt: 240
# Bad ttfex fltpos: 240
# Bad ttfex fltpos_ps: 240
# Bad ttfex fltposfwhm: 240
# Bad ttfex proj_ref: 240
# Bad ttfex proj_sig: 240
# Bad ttfex refampl: 240
# 3308.4658719999998
# Bad ttfex ampl: 241
# Bad ttfex amplnxt: 241
# Bad ttfex fltpos: 241
# Bad ttfex fltpos_ps: 241
# Bad ttfex fltposfwhm: 241
# Bad ttfex proj_ref: 241
# Bad ttfex proj_sig: 241
# Bad ttfex refampl: 241
# 3308.325865
# Bad ttfex ampl: 242
# Bad ttfex amplnxt: 242
# Bad ttfex fltpos: 242
# Bad ttfex fltpos_ps: 242
# Bad ttfex fltposfwhm: 242
# Bad ttfex proj_ref: 242
# Bad ttfex proj_sig: 242
# Bad ttfex refampl: 242
# 3308.332532
# Bad ttfex ampl: 243
# Bad ttfex amplnxt: 243
# Bad ttfex fltpos: 243
# Bad ttfex fltpos_ps: 243
# Bad ttfex fltposfwhm: 243
# Bad ttfex proj_ref: 243
# Bad ttfex proj_sig: 243
# Bad ttfex refampl: 243
# 3308.305864
# Bad ttfex ampl: 244
# Bad ttfex amplnxt: 244
# Bad ttfex fltpos: 244
# Bad ttfex fltpos_ps: 244
# Bad ttfex fltposfwhm: 244
# Bad ttfex proj_ref: 244
# Bad ttfex proj_sig: 244
# Bad ttfex refampl: 244
# 3308.512541
# Bad ttfex ampl: 245
# Bad ttfex amplnxt: 245
# Bad ttfex fltpos: 245
# Bad ttfex fltpos_ps: 245
# Bad ttfex fltposfwhm: 245
# Bad ttfex proj_ref: 245
# Bad ttfex proj_sig: 245
# Bad ttfex refampl: 245
# 3308.392535
# 3308.5192079999997
# Bad ttfex ampl: 247
# Bad ttfex amplnxt: 247
# Bad ttfex fltpos: 247
# Bad ttfex fltpos_ps: 247
# Bad ttfex fltposfwhm: 247
# Bad ttfex proj_ref: 247
# Bad ttfex proj_sig: 247
# Bad ttfex refampl: 247
# 3308.4058689999997
# Bad ttfex ampl: 248
# Bad ttfex amplnxt: 248
# Bad ttfex fltpos: 248
# Bad ttfex fltpos_ps: 248
# Bad ttfex fltposfwhm: 248
# Bad ttfex proj_ref: 248
# Bad ttfex proj_sig: 248
# Bad ttfex refampl: 248
# 3308.479206
# Bad ttfex ampl: 249
# Bad ttfex amplnxt: 249
# Bad ttfex fltpos: 249
# Bad ttfex fltpos_ps: 249
# Bad ttfex fltposfwhm: 249
# Bad ttfex proj_ref: 249
# Bad ttfex proj_sig: 249
# Bad ttfex refampl: 249
# Event number: 250, Valid shots: 202
# 3308.365867
# Bad ttfex ampl: 250
# Bad ttfex amplnxt: 250
# Bad ttfex fltpos: 250
# Bad ttfex fltpos_ps: 250
# Bad ttfex fltposfwhm: 250
# Bad ttfex proj_ref: 250
# Bad ttfex proj_sig: 250
# Bad ttfex refampl: 250
# 3308.3725339999996
# Bad ttfex ampl: 251
# Bad ttfex amplnxt: 251
# Bad ttfex fltpos: 251
# Bad ttfex fltpos_ps: 251
# Bad ttfex fltposfwhm: 251
# Bad ttfex proj_ref: 251
# Bad ttfex proj_sig: 251
# Bad ttfex refampl: 251
# 3308.55921
# Bad ttfex ampl: 252
# Bad ttfex amplnxt: 252
# Bad ttfex fltpos: 252
# Bad ttfex fltpos_ps: 252
# Bad ttfex fltposfwhm: 252
# Bad ttfex proj_ref: 252
# Bad ttfex proj_sig: 252
# Bad ttfex refampl: 252
# 3308.332532
# Bad ttfex ampl: 253
# Bad ttfex amplnxt: 253
# Bad ttfex fltpos: 253
# Bad ttfex fltpos_ps: 253
# Bad ttfex fltposfwhm: 253
# Bad ttfex proj_ref: 253
# Bad ttfex proj_sig: 253
# Bad ttfex refampl: 253
# 3308.399202
# Bad ttfex ampl: 254
# Bad ttfex amplnxt: 254
# Bad ttfex fltpos: 254
# Bad ttfex fltpos_ps: 254
# Bad ttfex fltposfwhm: 254
# Bad ttfex proj_ref: 254
# Bad ttfex proj_sig: 254
# Bad ttfex refampl: 254
# 3308.42587
# Bad ttfex ampl: 255
# Bad ttfex amplnxt: 255
# Bad ttfex fltpos: 255
# Bad ttfex fltpos_ps: 255
# Bad ttfex fltposfwhm: 255
# Bad ttfex proj_ref: 255
# Bad ttfex proj_sig: 255
# Bad ttfex refampl: 255
# 3308.4058689999997
# Bad ttfex ampl: 256
# Bad ttfex amplnxt: 256
# Bad ttfex fltpos: 256
# Bad ttfex fltpos_ps: 256
# Bad ttfex fltposfwhm: 256
# Bad ttfex proj_ref: 256
# Bad ttfex proj_sig: 256
# Bad ttfex refampl: 256
# 3308.552543
# Bad ttfex ampl: 257
# Bad ttfex amplnxt: 257
# Bad ttfex fltpos: 257
# Bad ttfex fltpos_ps: 257
# Bad ttfex fltposfwhm: 257
# Bad ttfex proj_ref: 257
# Bad ttfex proj_sig: 257
# Bad ttfex refampl: 257
# 3308.4058689999997
# Bad ttfex ampl: 258
# Bad ttfex amplnxt: 258
# Bad ttfex fltpos: 258
# Bad ttfex fltpos_ps: 258
# Bad ttfex fltposfwhm: 258
# Bad ttfex proj_ref: 258
# Bad ttfex proj_sig: 258
# Bad ttfex refampl: 258
# 3308.3458659999997
# Bad ttfex ampl: 259
# Bad ttfex amplnxt: 259
# Bad ttfex fltpos: 259
# Bad ttfex fltpos_ps: 259
# Bad ttfex fltposfwhm: 259
# Bad ttfex proj_ref: 259
# Bad ttfex proj_sig: 259
# Bad ttfex refampl: 259
# 3308.3792009999997
# Bad ttfex ampl: 260
# Bad ttfex amplnxt: 260
# Bad ttfex fltpos: 260
# Bad ttfex fltpos_ps: 260
# Bad ttfex fltposfwhm: 260
# Bad ttfex proj_ref: 260
# Bad ttfex proj_sig: 260
# Bad ttfex refampl: 260
# 3308.445871
# Bad ttfex ampl: 261
# Bad ttfex amplnxt: 261
# Bad ttfex fltpos: 261
# Bad ttfex fltpos_ps: 261
# Bad ttfex fltposfwhm: 261
# Bad ttfex proj_ref: 261
# Bad ttfex proj_sig: 261
# Bad ttfex refampl: 261
# 3308.412536
# Bad ttfex ampl: 262
# Bad ttfex amplnxt: 262
# Bad ttfex fltpos: 262
# Bad ttfex fltpos_ps: 262
# Bad ttfex fltposfwhm: 262
# Bad ttfex proj_ref: 262
# Bad ttfex proj_sig: 262
# Bad ttfex refampl: 262
# 3308.472539
# Bad ttfex ampl: 263
# Bad ttfex amplnxt: 263
# Bad ttfex fltpos: 263
# Bad ttfex fltpos_ps: 263
# Bad ttfex fltposfwhm: 263
# Bad ttfex proj_ref: 263
# Bad ttfex proj_sig: 263
# Bad ttfex refampl: 263
# 3308.4058689999997
# Bad ttfex ampl: 264
# Bad ttfex amplnxt: 264
# Bad ttfex fltpos: 264
# Bad ttfex fltpos_ps: 264
# Bad ttfex fltposfwhm: 264
# Bad ttfex proj_ref: 264
# Bad ttfex proj_sig: 264
# Bad ttfex refampl: 264
# 3308.3792009999997
# 3308.4325369999997
# Bad ttfex ampl: 266
# Bad ttfex amplnxt: 266
# Bad ttfex fltpos: 266
# Bad ttfex fltpos_ps: 266
# Bad ttfex fltposfwhm: 266
# Bad ttfex proj_ref: 266
# Bad ttfex proj_sig: 266
# Bad ttfex refampl: 266
# 3308.412536
# 3308.512541
# Bad ttfex ampl: 268
# Bad ttfex amplnxt: 268
# Bad ttfex fltpos: 268
# Bad ttfex fltpos_ps: 268
# Bad ttfex fltposfwhm: 268
# Bad ttfex proj_ref: 268
# Bad ttfex proj_sig: 268
# Bad ttfex refampl: 268
# 3308.565877
# 3308.392535
# 3308.3525329999998
# Bad ttfex ampl: 271
# Bad ttfex amplnxt: 271
# Bad ttfex fltpos: 271
# Bad ttfex fltpos_ps: 271
# Bad ttfex fltposfwhm: 271
# Bad ttfex proj_ref: 271
# Bad ttfex proj_sig: 271
# Bad ttfex refampl: 271
# 3308.512541
# Bad ttfex ampl: 272
# Bad ttfex amplnxt: 272
# Bad ttfex fltpos: 272
# Bad ttfex fltpos_ps: 272
# Bad ttfex fltposfwhm: 272
# Bad ttfex proj_ref: 272
# Bad ttfex proj_sig: 272
# Bad ttfex refampl: 272
# 3308.412536
# Bad ttfex ampl: 273
# Bad ttfex amplnxt: 273
# Bad ttfex fltpos: 273
# Bad ttfex fltpos_ps: 273
# Bad ttfex fltposfwhm: 273
# Bad ttfex proj_ref: 273
# Bad ttfex proj_sig: 273
# Bad ttfex refampl: 273
# 3308.4325369999997
# Bad ttfex ampl: 274
# Bad ttfex amplnxt: 274
# Bad ttfex fltpos: 274
# Bad ttfex fltpos_ps: 274
# Bad ttfex fltposfwhm: 274
# Bad ttfex proj_ref: 274
# Bad ttfex proj_sig: 274
# Bad ttfex refampl: 274
# 3308.3191979999997
# Bad ttfex ampl: 275
# Bad ttfex amplnxt: 275
# Bad ttfex fltpos: 275
# Bad ttfex fltpos_ps: 275
# Bad ttfex fltposfwhm: 275
# Bad ttfex proj_ref: 275
# Bad ttfex proj_sig: 275
# Bad ttfex refampl: 275
# 3308.305864
# Bad ttfex ampl: 276
# Bad ttfex amplnxt: 276
# Bad ttfex fltpos: 276
# Bad ttfex fltpos_ps: 276
# Bad ttfex fltposfwhm: 276
# Bad ttfex proj_ref: 276
# Bad ttfex proj_sig: 276
# Bad ttfex refampl: 276
# 3308.472539
# Bad ttfex ampl: 277
# Bad ttfex amplnxt: 277
# Bad ttfex fltpos: 277
# Bad ttfex fltpos_ps: 277
# Bad ttfex fltposfwhm: 277
# Bad ttfex proj_ref: 277
# Bad ttfex proj_sig: 277
# Bad ttfex refampl: 277
# 3308.525875
# Bad ttfex ampl: 278
# Bad ttfex amplnxt: 278
# Bad ttfex fltpos: 278
# Bad ttfex fltpos_ps: 278
# Bad ttfex fltposfwhm: 278
# Bad ttfex proj_ref: 278
# Bad ttfex proj_sig: 278
# Bad ttfex refampl: 278
# 3308.392535
# Bad ttfex ampl: 279
# Bad ttfex amplnxt: 279
# Bad ttfex fltpos: 279
# Bad ttfex fltpos_ps: 279
# Bad ttfex fltposfwhm: 279
# Bad ttfex proj_ref: 279
# Bad ttfex proj_sig: 279
# Bad ttfex refampl: 279
# 3308.479206
# Bad ttfex ampl: 280
# Bad ttfex amplnxt: 280
# Bad ttfex fltpos: 280
# Bad ttfex fltpos_ps: 280
# Bad ttfex fltposfwhm: 280
# Bad ttfex proj_ref: 280
# Bad ttfex proj_sig: 280
# Bad ttfex refampl: 280
# 3308.412536
# Bad ttfex ampl: 281
# Bad ttfex amplnxt: 281
# Bad ttfex fltpos: 281
# Bad ttfex fltpos_ps: 281
# Bad ttfex fltposfwhm: 281
# Bad ttfex proj_ref: 281
# Bad ttfex proj_sig: 281
# Bad ttfex refampl: 281
# 3308.439204
# Bad ttfex ampl: 282
# Bad ttfex amplnxt: 282
# Bad ttfex fltpos: 282
# Bad ttfex fltpos_ps: 282
# Bad ttfex fltposfwhm: 282
# Bad ttfex proj_ref: 282
# Bad ttfex proj_sig: 282
# Bad ttfex refampl: 282
# 3308.339199
# Bad ttfex ampl: 283
# Bad ttfex amplnxt: 283
# Bad ttfex fltpos: 283
# Bad ttfex fltpos_ps: 283
# Bad ttfex fltposfwhm: 283
# Bad ttfex proj_ref: 283
# Bad ttfex proj_sig: 283
# Bad ttfex refampl: 283
# 3308.445871
# Bad ttfex ampl: 284
# Bad ttfex amplnxt: 284
# Bad ttfex fltpos: 284
# Bad ttfex fltpos_ps: 284
# Bad ttfex fltposfwhm: 284
# Bad ttfex proj_ref: 284
# Bad ttfex proj_sig: 284
# Bad ttfex refampl: 284
# 3308.4325369999997
# Bad ttfex ampl: 285
# Bad ttfex amplnxt: 285
# Bad ttfex fltpos: 285
# Bad ttfex fltpos_ps: 285
# Bad ttfex fltposfwhm: 285
# Bad ttfex proj_ref: 285
# Bad ttfex proj_sig: 285
# Bad ttfex refampl: 285
# 3308.445871
# Bad ttfex ampl: 286
# Bad ttfex amplnxt: 286
# Bad ttfex fltpos: 286
# Bad ttfex fltpos_ps: 286
# Bad ttfex fltposfwhm: 286
# Bad ttfex proj_ref: 286
# Bad ttfex proj_sig: 286
# Bad ttfex refampl: 286
# 3308.412536
# Bad ttfex ampl: 287
# Bad ttfex amplnxt: 287
# Bad ttfex fltpos: 287
# Bad ttfex fltpos_ps: 287
# Bad ttfex fltposfwhm: 287
# Bad ttfex proj_ref: 287
# Bad ttfex proj_sig: 287
# Bad ttfex refampl: 287
# 3308.385868
# Bad ttfex ampl: 288
# Bad ttfex amplnxt: 288
# Bad ttfex fltpos: 288
# Bad ttfex fltpos_ps: 288
# Bad ttfex fltposfwhm: 288
# Bad ttfex proj_ref: 288
# Bad ttfex proj_sig: 288
# Bad ttfex refampl: 288
# 3308.499207
# Bad ttfex ampl: 289
# Bad ttfex amplnxt: 289
# Bad ttfex fltpos: 289
# Bad ttfex fltpos_ps: 289
# Bad ttfex fltposfwhm: 289
# Bad ttfex proj_ref: 289
# Bad ttfex proj_sig: 289
# Bad ttfex refampl: 289
# 3308.4592049999997
# Bad ttfex ampl: 290
# Bad ttfex amplnxt: 290
# Bad ttfex fltpos: 290
# Bad ttfex fltpos_ps: 290
# Bad ttfex fltposfwhm: 290
# Bad ttfex proj_ref: 290
# Bad ttfex proj_sig: 290
# Bad ttfex refampl: 290
# 3308.539209
# Bad ttfex ampl: 291
# Bad ttfex amplnxt: 291
# Bad ttfex fltpos: 291
# Bad ttfex fltpos_ps: 291
# Bad ttfex fltposfwhm: 291
# Bad ttfex proj_ref: 291
# Bad ttfex proj_sig: 291
# Bad ttfex refampl: 291
# 3308.392535
# 3308.385868
# Bad ttfex ampl: 293
# Bad ttfex amplnxt: 293
# Bad ttfex fltpos: 293
# Bad ttfex fltpos_ps: 293
# Bad ttfex fltposfwhm: 293
# Bad ttfex proj_ref: 293
# Bad ttfex proj_sig: 293
# Bad ttfex refampl: 293
# 3308.505874
# Bad ttfex ampl: 294
# Bad ttfex amplnxt: 294
# Bad ttfex fltpos: 294
# Bad ttfex fltpos_ps: 294
# Bad ttfex fltposfwhm: 294
# Bad ttfex proj_ref: 294
# Bad ttfex proj_sig: 294
# Bad ttfex refampl: 294
# 3308.4325369999997
# Bad ttfex ampl: 295
# Bad ttfex amplnxt: 295
# Bad ttfex fltpos: 295
# Bad ttfex fltpos_ps: 295
# Bad ttfex fltposfwhm: 295
# Bad ttfex proj_ref: 295
# Bad ttfex proj_sig: 295
# Bad ttfex refampl: 295
# 3308.479206
# 3308.365867
# Bad ttfex ampl: 297
# Bad ttfex amplnxt: 297
# Bad ttfex fltpos: 297
# Bad ttfex fltpos_ps: 297
# Bad ttfex fltposfwhm: 297
# Bad ttfex proj_ref: 297
# Bad ttfex proj_sig: 297
# Bad ttfex refampl: 297
# 3308.452538
# 3308.4058689999997
# Event number: 300, Valid shots: 252
# 3308.439204
# Bad ttfex ampl: 300
# Bad ttfex amplnxt: 300
# Bad ttfex fltpos: 300
# Bad ttfex fltpos_ps: 300
# Bad ttfex fltposfwhm: 300
# Bad ttfex proj_ref: 300
# Bad ttfex proj_sig: 300
# Bad ttfex refampl: 300
# 3308.439204
# Bad ttfex ampl: 301
# Bad ttfex amplnxt: 301
# Bad ttfex fltpos: 301
# Bad ttfex fltpos_ps: 301
# Bad ttfex fltposfwhm: 301
# Bad ttfex proj_ref: 301
# Bad ttfex proj_sig: 301
# Bad ttfex refampl: 301
# 3308.412536
# Bad ttfex ampl: 302
# Bad ttfex amplnxt: 302
# Bad ttfex fltpos: 302
# Bad ttfex fltpos_ps: 302
# Bad ttfex fltposfwhm: 302
# Bad ttfex proj_ref: 302
# Bad ttfex proj_sig: 302
# Bad ttfex refampl: 302
# 3308.419203
# Bad ttfex ampl: 303
# Bad ttfex amplnxt: 303
# Bad ttfex fltpos: 303
# Bad ttfex fltpos_ps: 303
# Bad ttfex fltposfwhm: 303
# Bad ttfex proj_ref: 303
# Bad ttfex proj_sig: 303
# Bad ttfex refampl: 303
# 3308.339199
# Bad ttfex ampl: 304
# Bad ttfex amplnxt: 304
# Bad ttfex fltpos: 304
# Bad ttfex fltpos_ps: 304
# Bad ttfex fltposfwhm: 304
# Bad ttfex proj_ref: 304
# Bad ttfex proj_sig: 304
# Bad ttfex refampl: 304
# 3308.4658719999998
# Bad ttfex ampl: 305
# Bad ttfex amplnxt: 305
# Bad ttfex fltpos: 305
# Bad ttfex fltpos_ps: 305
# Bad ttfex fltposfwhm: 305
# Bad ttfex proj_ref: 305
# Bad ttfex proj_sig: 305
# Bad ttfex refampl: 305
# 3308.399202
# 3308.4858729999996
# Bad ttfex ampl: 307
# Bad ttfex amplnxt: 307
# Bad ttfex fltpos: 307
# Bad ttfex fltpos_ps: 307
# Bad ttfex fltposfwhm: 307
# Bad ttfex proj_ref: 307
# Bad ttfex proj_sig: 307
# Bad ttfex refampl: 307
# 3308.3725339999996
# 3308.332532
# Bad ttfex ampl: 309
# Bad ttfex amplnxt: 309
# Bad ttfex fltpos: 309
# Bad ttfex fltpos_ps: 309
# Bad ttfex fltposfwhm: 309
# Bad ttfex proj_ref: 309
# Bad ttfex proj_sig: 309
# Bad ttfex refampl: 309
# 3308.4658719999998
# 3308.4058689999997
# Bad ttfex ampl: 311
# Bad ttfex amplnxt: 311
# Bad ttfex fltpos: 311
# Bad ttfex fltpos_ps: 311
# Bad ttfex fltposfwhm: 311
# Bad ttfex proj_ref: 311
# Bad ttfex proj_sig: 311
# Bad ttfex refampl: 311
# 3308.439204
# Bad ttfex ampl: 312
# Bad ttfex amplnxt: 312
# Bad ttfex fltpos: 312
# Bad ttfex fltpos_ps: 312
# Bad ttfex fltposfwhm: 312
# Bad ttfex proj_ref: 312
# Bad ttfex proj_sig: 312
# Bad ttfex refampl: 312
# 3308.392535
# Bad ttfex ampl: 313
# Bad ttfex amplnxt: 313
# Bad ttfex fltpos: 313
# Bad ttfex fltpos_ps: 313
# Bad ttfex fltposfwhm: 313
# Bad ttfex proj_ref: 313
# Bad ttfex proj_sig: 313
# Bad ttfex refampl: 313
# 3308.399202
# Bad ttfex ampl: 314
# Bad ttfex amplnxt: 314
# Bad ttfex fltpos: 314
# Bad ttfex fltpos_ps: 314
# Bad ttfex fltposfwhm: 314
# Bad ttfex proj_ref: 314
# Bad ttfex proj_sig: 314
# Bad ttfex refampl: 314
# 3308.472539
# Bad ttfex ampl: 315
# Bad ttfex amplnxt: 315
# Bad ttfex fltpos: 315
# Bad ttfex fltpos_ps: 315
# Bad ttfex fltposfwhm: 315
# Bad ttfex proj_ref: 315
# Bad ttfex proj_sig: 315
# Bad ttfex refampl: 315
# 3308.3458659999997
# Bad ttfex ampl: 316
# Bad ttfex amplnxt: 316
# Bad ttfex fltpos: 316
# Bad ttfex fltpos_ps: 316
# Bad ttfex fltposfwhm: 316
# Bad ttfex proj_ref: 316
# Bad ttfex proj_sig: 316
# Bad ttfex refampl: 316
# 3308.439204
# Bad ttfex ampl: 317
# Bad ttfex amplnxt: 317
# Bad ttfex fltpos: 317
# Bad ttfex fltpos_ps: 317
# Bad ttfex fltposfwhm: 317
# Bad ttfex proj_ref: 317
# Bad ttfex proj_sig: 317
# Bad ttfex refampl: 317
# 3308.439204
# Bad ttfex ampl: 318
# Bad ttfex amplnxt: 318
# Bad ttfex fltpos: 318
# Bad ttfex fltpos_ps: 318
# Bad ttfex fltposfwhm: 318
# Bad ttfex proj_ref: 318
# Bad ttfex proj_sig: 318
# Bad ttfex refampl: 318
# 3308.385868
# Bad ttfex ampl: 319
# Bad ttfex amplnxt: 319
# Bad ttfex fltpos: 319
# Bad ttfex fltpos_ps: 319
# Bad ttfex fltposfwhm: 319
# Bad ttfex proj_ref: 319
# Bad ttfex proj_sig: 319
# Bad ttfex refampl: 319
# 3308.4325369999997
# Bad ttfex ampl: 320
# Bad ttfex amplnxt: 320
# Bad ttfex fltpos: 320
# Bad ttfex fltpos_ps: 320
# Bad ttfex fltposfwhm: 320
# Bad ttfex proj_ref: 320
# Bad ttfex proj_sig: 320
# Bad ttfex refampl: 320
# 3308.419203
# Bad ttfex ampl: 321
# Bad ttfex amplnxt: 321
# Bad ttfex fltpos: 321
# Bad ttfex fltpos_ps: 321
# Bad ttfex fltposfwhm: 321
# Bad ttfex proj_ref: 321
# Bad ttfex proj_sig: 321
# Bad ttfex refampl: 321
# 3308.539209
# Bad ttfex ampl: 322
# Bad ttfex amplnxt: 322
# ...
# Bad ttfex proj_ref: 4970
# Bad ttfex proj_sig: 4970
# Bad ttfex refampl: 4970
# 3308.3525329999998
# Bad ttfex ampl: 4971
# Bad ttfex amplnxt: 4971
# Bad ttfex fltpos: 4971
# Bad ttfex fltpos_ps: 4971
# Bad ttfex fltposfwhm: 4971
# Bad ttfex proj_ref: 4971
# Bad ttfex proj_sig: 4971
# Bad ttfex refampl: 4971
# 3308.525875
# 3308.412536
# Bad ttfex ampl: 4973
# Bad ttfex amplnxt: 4973
# Bad ttfex fltpos: 4973
# Bad ttfex fltpos_ps: 4973
# Bad ttfex fltposfwhm: 4973
# Bad ttfex proj_ref: 4973
# Bad ttfex proj_sig: 4973
# Bad ttfex refampl: 4973
# 3308.3592
# 3308.4592049999997
# Bad ttfex ampl: 4975
# Bad ttfex amplnxt: 4975
# Bad ttfex fltpos: 4975
# Bad ttfex fltpos_ps: 4975
# Bad ttfex fltposfwhm: 4975
# Bad ttfex proj_ref: 4975
# Bad ttfex proj_sig: 4975
# Bad ttfex refampl: 4975
# 3308.505874
# Bad ttfex ampl: 4976
# Bad ttfex amplnxt: 4976
# Bad ttfex fltpos: 4976
# Bad ttfex fltpos_ps: 4976
# Bad ttfex fltposfwhm: 4976
# Bad ttfex proj_ref: 4976
# Bad ttfex proj_sig: 4976
# Bad ttfex refampl: 4976
# 3308.3725339999996
# Bad ttfex ampl: 4977
# Bad ttfex amplnxt: 4977
# Bad ttfex fltpos: 4977
# Bad ttfex fltpos_ps: 4977
# Bad ttfex fltposfwhm: 4977
# Bad ttfex proj_ref: 4977
# Bad ttfex proj_sig: 4977
# Bad ttfex refampl: 4977
# 3308.4858729999996
# Bad ttfex ampl: 4978
# Bad ttfex amplnxt: 4978
# Bad ttfex fltpos: 4978
# Bad ttfex fltpos_ps: 4978
# Bad ttfex fltposfwhm: 4978
# Bad ttfex proj_ref: 4978
# Bad ttfex proj_sig: 4978
# Bad ttfex refampl: 4978
# 3308.412536
# Bad ttfex ampl: 4979
# Bad ttfex amplnxt: 4979
# Bad ttfex fltpos: 4979
# Bad ttfex fltpos_ps: 4979
# Bad ttfex fltposfwhm: 4979
# Bad ttfex proj_ref: 4979
# Bad ttfex proj_sig: 4979
# Bad ttfex refampl: 4979
# 3308.445871
# Bad ttfex ampl: 4980
# Bad ttfex amplnxt: 4980
# Bad ttfex fltpos: 4980
# Bad ttfex fltpos_ps: 4980
# Bad ttfex fltposfwhm: 4980
# Bad ttfex proj_ref: 4980
# Bad ttfex proj_sig: 4980
# Bad ttfex refampl: 4980
# 3308.42587
# 3308.445871
# Bad ttfex ampl: 4982
# Bad ttfex amplnxt: 4982
# Bad ttfex fltpos: 4982
# Bad ttfex fltpos_ps: 4982
# Bad ttfex fltposfwhm: 4982
# Bad ttfex proj_ref: 4982
# Bad ttfex proj_sig: 4982
# Bad ttfex refampl: 4982
# 3308.419203
# 3308.3458659999997
# Bad ttfex ampl: 4984
# Bad ttfex amplnxt: 4984
# Bad ttfex fltpos: 4984
# Bad ttfex fltpos_ps: 4984
# Bad ttfex fltposfwhm: 4984
# Bad ttfex proj_ref: 4984
# Bad ttfex proj_sig: 4984
# Bad ttfex refampl: 4984
# 3308.385868
# Bad ttfex ampl: 4985
# Bad ttfex amplnxt: 4985
# Bad ttfex fltpos: 4985
# Bad ttfex fltpos_ps: 4985
# Bad ttfex fltposfwhm: 4985
# Bad ttfex proj_ref: 4985
# Bad ttfex proj_sig: 4985
# Bad ttfex refampl: 4985
# 3308.499207
# 3308.472539
# Bad ttfex ampl: 4987
# Bad ttfex amplnxt: 4987
# Bad ttfex fltpos: 4987
# Bad ttfex fltpos_ps: 4987
# Bad ttfex fltposfwhm: 4987
# Bad ttfex proj_ref: 4987
# Bad ttfex proj_sig: 4987
# Bad ttfex refampl: 4987
# 3308.4325369999997
# Bad ttfex ampl: 4988
# Bad ttfex amplnxt: 4988
# Bad ttfex fltpos: 4988
# Bad ttfex fltpos_ps: 4988
# Bad ttfex fltposfwhm: 4988
# Bad ttfex proj_ref: 4988
# Bad ttfex proj_sig: 4988
# Bad ttfex refampl: 4988
# 3308.505874
# Bad ttfex ampl: 4989
# Bad ttfex amplnxt: 4989
# Bad ttfex fltpos: 4989
# Bad ttfex fltpos_ps: 4989
# Bad ttfex fltposfwhm: 4989
# Bad ttfex proj_ref: 4989
# Bad ttfex proj_sig: 4989
# Bad ttfex refampl: 4989
# 3308.392535
# Bad ttfex ampl: 4990
# Bad ttfex amplnxt: 4990
# Bad ttfex fltpos: 4990
# Bad ttfex fltpos_ps: 4990
# Bad ttfex fltposfwhm: 4990
# Bad ttfex proj_ref: 4990
# Bad ttfex proj_sig: 4990
# Bad ttfex refampl: 4990
# 3308.4325369999997
# Bad ttfex ampl: 4991
# Bad ttfex amplnxt: 4991
# Bad ttfex fltpos: 4991
# Bad ttfex fltpos_ps: 4991
# Bad ttfex fltposfwhm: 4991
# Bad ttfex proj_ref: 4991
# Bad ttfex proj_sig: 4991
# Bad ttfex refampl: 4991
# 3308.399202
# Bad ttfex ampl: 4992
# Bad ttfex amplnxt: 4992
# Bad ttfex fltpos: 4992
# Bad ttfex fltpos_ps: 4992
# Bad ttfex fltposfwhm: 4992
# Bad ttfex proj_ref: 4992
# Bad ttfex proj_sig: 4992
# Bad ttfex refampl: 4992
# 3308.3592
# Bad ttfex ampl: 4993
# Bad ttfex amplnxt: 4993
# Bad ttfex fltpos: 4993
# Bad ttfex fltpos_ps: 4993
# Bad ttfex fltposfwhm: 4993
# Bad ttfex proj_ref: 4993
# Bad ttfex proj_sig: 4993
# Bad ttfex refampl: 4993
# 3308.479206
# Bad ttfex ampl: 4994
# Bad ttfex amplnxt: 4994
# Bad ttfex fltpos: 4994
# Bad ttfex fltpos_ps: 4994
# Bad ttfex fltposfwhm: 4994
# Bad ttfex proj_ref: 4994
# Bad ttfex proj_sig: 4994
# Bad ttfex refampl: 4994
# 3308.385868
# Bad ttfex ampl: 4995
# Bad ttfex amplnxt: 4995
# Bad ttfex fltpos: 4995
# Bad ttfex fltpos_ps: 4995
# Bad ttfex fltposfwhm: 4995
# Bad ttfex proj_ref: 4995
# Bad ttfex proj_sig: 4995
# Bad ttfex refampl: 4995
# 3308.512541
# Bad ttfex ampl: 4996
# Bad ttfex amplnxt: 4996
# Bad ttfex fltpos: 4996
# Bad ttfex fltpos_ps: 4996
# Bad ttfex fltposfwhm: 4996
# Bad ttfex proj_ref: 4996
# Bad ttfex proj_sig: 4996
# Bad ttfex refampl: 4996
# 3308.3792009999997
# Bad ttfex ampl: 4997
# Bad ttfex amplnxt: 4997
# Bad ttfex fltpos: 4997
# Bad ttfex fltpos_ps: 4997
# Bad ttfex fltposfwhm: 4997
# Bad ttfex proj_ref: 4997
# Bad ttfex proj_sig: 4997
# Bad ttfex refampl: 4997
# 3308.285863
# Bad ttfex ampl: 4998
# Bad ttfex amplnxt: 4998
# Bad ttfex fltpos: 4998
# Bad ttfex fltpos_ps: 4998
# Bad ttfex fltposfwhm: 4998
# Bad ttfex proj_ref: 4998
# Bad ttfex proj_sig: 4998
# Bad ttfex refampl: 4998
# 3308.525875
# Bad ttfex ampl: 4999
# Bad ttfex amplnxt: 4999
# Bad ttfex fltpos: 4999
# Bad ttfex fltpos_ps: 4999
# Bad ttfex fltposfwhm: 4999
# Bad ttfex proj_ref: 4999
# Bad ttfex proj_sig: 4999
# Bad ttfex refampl: 4999
# Event number: 5000, Valid shots: 4931
# 3308.419203
# Bad ttfex ampl: 5000
# Bad ttfex amplnxt: 5000
# Bad ttfex fltpos: 5000
# Bad ttfex fltpos_ps: 5000
# Bad ttfex fltposfwhm: 5000
# Bad ttfex proj_ref: 5000
# Bad ttfex proj_sig: 5000
# Bad ttfex refampl: 5000
# 3308.399202
# Bad ttfex ampl: 5001
# Bad ttfex amplnxt: 5001
# Bad ttfex fltpos: 5001
# Bad ttfex fltpos_ps: 5001
# Bad ttfex fltposfwhm: 5001
# Bad ttfex proj_ref: 5001
# Bad ttfex proj_sig: 5001
# Bad ttfex refampl: 5001
# 3308.4325369999997
# Bad ttfex ampl: 5002
# Bad ttfex amplnxt: 5002
# Bad ttfex fltpos: 5002
# Bad ttfex fltpos_ps: 5002
# Bad ttfex fltposfwhm: 5002
# Bad ttfex proj_ref: 5002
# Bad ttfex proj_sig: 5002
# Bad ttfex refampl: 5002
# 3308.4058689999997
# Bad ttfex ampl: 5003
# Bad ttfex amplnxt: 5003
# Bad ttfex fltpos: 5003
# Bad ttfex fltpos_ps: 5003
# Bad ttfex fltposfwhm: 5003
# Bad ttfex proj_ref: 5003
# Bad ttfex proj_sig: 5003
# Bad ttfex refampl: 5003
# 3308.419203
# Bad ttfex ampl: 5004
# Bad ttfex amplnxt: 5004
# Bad ttfex fltpos: 5004
# Bad ttfex fltpos_ps: 5004
# Bad ttfex fltposfwhm: 5004
# Bad ttfex proj_ref: 5004
# Bad ttfex proj_sig: 5004
# Bad ttfex refampl: 5004
# 3308.499207
# Bad ttfex ampl: 5005
# Bad ttfex amplnxt: 5005
# Bad ttfex fltpos: 5005
# Bad ttfex fltpos_ps: 5005
# Bad ttfex fltposfwhm: 5005
# Bad ttfex proj_ref: 5005
# Bad ttfex proj_sig: 5005
# Bad ttfex refampl: 5005
# andor: 5006
# andor: 5007
# andor: 5008
# andor: 5009
# andor: 5010
# andor: 5011
# andor: 5012
# andor: 5013
# andor: 5014
# andor: 5015
# andor: 5016
# andor: 5017
# andor: 5018
# andor: 5019
# andor: 5020
# andor: 5021
# andor: 5022
# andor: 5023
# andor: 5024
# andor: 5025
# andor: 5026
# andor: 5027
# andor: 5028
# andor: 5029
# andor: 5030
# andor: 5031
# andor: 5032
# andor: 5033
# andor: 5034
# andor: 5035
# andor: 5036
# andor: 5037
# andor: 5038
# andor: 5039
# andor: 5040
# andor: 5041
# andor: 5042
# andor: 5043
# andor: 5044
# andor: 5045
# andor: 5046
# andor: 5047
# andor: 5048
# andor: 5049
# Event number: 5050, Valid shots: 4937
# andor: 5050
# andor: 5051
# andor: 5052
# andor: 5053
# andor: 5054
# andor: 5055
# andor: 5056
# andor: 5057
# andor: 5058
# andor: 5059
# andor: 5060
# andor: 5061
# andor: 5062
# andor: 5063
# andor: 5064
# andor: 5065
# andor: 5066
# andor: 5067
# andor: 5068
# andor: 5069
# andor: 5070
# andor: 5071
# andor: 5072
# andor: 5073
# andor: 5074
# andor: 5075
# andor: 5076
# andor: 5077
# andor: 5078
# andor: 5079
# andor: 5080
# andor: 5081
# andor: 5082
# andor: 5083
# andor: 5084
# andor: 5085
# andor: 5086
# andor: 5087
# andor: 5088
# andor: 5089
# andor: 5090
# andor: 5091
# andor: 5092
# andor: 5093
# andor: 5094
# andor: 5095
# andor: 5096
# andor: 5097
# andor: 5098
# andor: 5099
# Event number: 5100, Valid shots: 4937
# andor: 5100
# andor: 5101
# andor: 5102
# andor: 5103
# andor: 5104
# andor: 5105
# andor: 5106
# andor: 5107
# andor: 5108
# andor: 5109
# andor: 5110
# andor: 5111
# andor: 5112
# andor: 5113
# andor: 5114
# andor: 5115
# andor: 5116
# andor: 5117
# andor: 5118
# andor: 5119
# andor: 5120
# andor: 5121
# andor: 5122
# andor: 5123
# andor: 5124
# andor: 5125
# andor: 5126
# andor: 5127
# andor: 5128
# andor: 5129
# andor: 5130
# andor: 5131
# andor: 5132
# andor: 5133
# andor: 5134
# andor: 5135
# andor: 5136
# andor: 5137
# andor: 5138
# andor: 5139
# andor: 5140
# andor: 5141
# andor: 5142
# andor: 5143
# andor: 5144
# andor: 5145
# andor: 5146
# andor: 5147
# andor: 5148
# andor: 5149
# Event number: 5150, Valid shots: 4937
# andor: 5150
# andor: 5151
# andor: 5152
# andor: 5153
# andor: 5154
# andor: 5155
# andor: 5156
# andor: 5157
# andor: 5158
# andor: 5159
# andor: 5160
# andor: 5161
# andor: 5162
# andor: 5163
# andor: 5164
# andor: 5165
# andor: 5166
# andor: 5167
# andor: 5168
# andor: 5169
# andor: 5170
# andor: 5171
# andor: 5172
# andor: 5173
# andor: 5174
# andor: 5175
# andor: 5176
# andor: 5177
# andor: 5178
# andor: 5179
# andor: 5180
# andor: 5181
# andor: 5182
# andor: 5183
# andor: 5184
# andor: 5185
# andor: 5186
# andor: 5187
# andor: 5188
# andor: 5189
# andor: 5190
# andor: 5191
# andor: 5192
# andor: 5193
# andor: 5194
# andor: 5195
# andor: 5196
# andor: 5197
# andor: 5198
# andor: 5199
# Event number: 5200, Valid shots: 4937
# andor: 5200
# andor: 5201
# andor: 5202
# andor: 5203
# andor: 5204
# andor: 5205
# andor: 5206
# andor: 5207
# andor: 5208
# andor: 5209
# andor: 5210
# andor: 5211
# andor: 5212
# andor: 5213
# andor: 5214
# andor: 5215
# andor: 5216
# andor: 5217
# andor: 5218
# andor: 5219
# andor: 5220
# andor: 5221
# andor: 5222
# andor: 5223
# andor: 5224
# andor: 5225
# andor: 5226
# andor: 5227
# andor: 5228
# andor: 5229
# andor: 5230
# andor: 5231
# andor: 5232
# andor: 5233
# andor: 5234
# andor: 5235
# andor: 5236
# andor: 5237
# andor: 5238
# andor: 5239
# andor: 5240
# andor: 5241
# andor: 5242
# andor: 5243
# andor: 5244
# andor: 5245
# andor: 5246
# andor: 5247
# andor: 5248
# andor: 5249
# Event number: 5250, Valid shots: 4937
# andor: 5250
# andor: 5251
# andor: 5252
# andor: 5253
# andor: 5254
# andor: 5255
# andor: 5256
# andor: 5257
# andor: 5258
# andor: 5259
# andor: 5260
# andor: 5261
# andor: 5262
# andor: 5263
# andor: 5264
# andor: 5265
# andor: 5266
# andor: 5267
# andor: 5268
# andor: 5269
# andor: 5270
# andor: 5271
# andor: 5272
# andor: 5273
# andor: 5274
# andor: 5275
# andor: 5276
# andor: 5277
# andor: 5278
# andor: 5279
# andor: 5280
# andor: 5281
# andor: 5282
# andor: 5283
# andor: 5284
# andor: 5285
# andor: 5286
# andor: 5287
# andor: 5288
# andor: 5289
# andor: 5290
# andor: 5291
# andor: 5292
# andor: 5293
# andor: 5294
# andor: 5295
# andor: 5296
# andor: 5297
# andor: 5298
# andor: 5299
# Event number: 5300, Valid shots: 4937
# andor: 5300
# andor: 5301
# andor: 5302
# andor: 5303
# andor: 5304
# andor: 5305
# andor: 5306
# andor: 5307
# andor: 5308
# andor: 5309
# andor: 5310
# andor: 5311
# andor: 5312
# andor: 5313
# andor: 5314
# andor: 5315
# andor: 5316
# andor: 5317
# andor: 5318
# andor: 5319
# andor: 5320
# andor: 5321
# andor: 5322
# andor: 5323
# andor: 5324
# andor: 5325
# andor: 5326
# andor: 5327
# andor: 5328
# andor: 5329
# andor: 5330
# andor: 5331
# andor: 5332
# andor: 5333
# andor: 5334
# andor: 5335
# andor: 5336
# andor: 5337
# andor: 5338
# andor: 5339
# andor: 5340
# andor: 5341
# andor: 5342
# andor: 5343
# andor: 5344
# andor: 5345
# andor: 5346
# andor: 5347
# andor: 5348
# andor: 5349
# Event number: 5350, Valid shots: 4937
# andor: 5350
# andor: 5351
# andor: 5352
# andor: 5353
# andor: 5354
# andor: 5355
# andor: 5356
# andor: 5357
# andor: 5358
# andor: 5359
# andor: 5360
# andor: 5361
# andor: 5362
# andor: 5363
# andor: 5364
# andor: 5365
# andor: 5366
# andor: 5367
# andor: 5368
# andor: 5369
# andor: 5370
# andor: 5371
# andor: 5372
# andor: 5373
# andor: 5374
# andor: 5375
# andor: 5376
# andor: 5377
# andor: 5378
# andor: 5379
# andor: 5380
# andor: 5381
# andor: 5382
# andor: 5383
# andor: 5384
# andor: 5385
# andor: 5386
# andor: 5387
# andor: 5388
# andor: 5389
# andor: 5390
# andor: 5391
# andor: 5392
# andor: 5393
# andor: 5394
# andor: 5395
# andor: 5396
# andor: 5397
# andor: 5398
# andor: 5399
# Event number: 5400, Valid shots: 4937
# andor: 5400
# andor: 5401
# andor: 5402
# andor: 5403
# andor: 5404
# andor: 5405
# andor: 5406
# andor: 5407
# andor: 5408
# andor: 5409
# andor: 5410
# andor: 5411
# andor: 5412
# andor: 5413
# andor: 5414
# andor: 5415
# andor: 5416
# andor: 5417
# andor: 5418
# andor: 5419
# andor: 5420
# andor: 5421
# andor: 5422
# andor: 5423
# andor: 5424
# andor: 5425
# andor: 5426
# andor: 5427
# andor: 5428
# andor: 5429
# andor: 5430
# andor: 5431
# andor: 5432
# andor: 5433
# andor: 5434
# andor: 5435
# andor: 5436
# andor: 5437
# andor: 5438
# andor: 5439
# andor: 5440
# andor: 5441
# andor: 5442
# andor: 5443
# andor: 5444
# andor: 5445
# andor: 5446
# andor: 5447
# andor: 5448
# andor: 5449
# Event number: 5450, Valid shots: 4937
# andor: 5450
# andor: 5451
# andor: 5452
# andor: 5453
# andor: 5454
# andor: 5455
# andor: 5456
# andor: 5457
# andor: 5458
# andor: 5459
# andor: 5460
# andor: 5461
# andor: 5462
# andor: 5463
# andor: 5464
# andor: 5465
# andor: 5466
# andor: 5467
# andor: 5468
# andor: 5469
# andor: 5470
# andor: 5471
# andor: 5472
# andor: 5473
# andor: 5474
# andor: 5475
# andor: 5476
# andor: 5477
# andor: 5478
# andor: 5479
# andor: 5480
# andor: 5481
# andor: 5482
# andor: 5483
# andor: 5484
# andor: 5485
# andor: 5486
# andor: 5487
# andor: 5488
# andor: 5489
# andor: 5490
# andor: 5491
# andor: 5492
# andor: 5493
# andor: 5494
# andor: 5495
# andor: 5496
# andor: 5497
# andor: 5498
# andor: 5499
# Event number: 5500, Valid shots: 4937
# andor: 5500
# andor: 5501
# andor: 5502
# andor: 5503
# andor: 5504
# andor: 5505
# andor: 5506
# andor: 5507
# andor: 5508
# andor: 5509
# andor: 5510
# andor: 5511
# andor: 5512
# andor: 5513
# andor: 5514
# andor: 5515
# andor: 5516
# andor: 5517
# andor: 5518
# andor: 5519
# andor: 5520
# andor: 5521
# andor: 5522
# andor: 5523
# andor: 5524
# andor: 5525
# andor: 5526
# andor: 5527
# andor: 5528
# andor: 5529
# andor: 5530
# andor: 5531
# andor: 5532
# andor: 5533
# andor: 5534
# andor: 5535
# andor: 5536
# andor: 5537
# andor: 5538
# andor: 5539
# andor: 5540
# andor: 5541
# andor: 5542
# andor: 5543
# andor: 5544
# andor: 5545
# andor: 5546
# andor: 5547
# andor: 5548
# andor: 5549
# Event number: 5550, Valid shots: 4937
# andor: 5550
# andor: 5551
# andor: 5552
# andor: 5553
# andor: 5554
# andor: 5555
# andor: 5556
# andor: 5557
# andor: 5558
# andor: 5559
# andor: 5560
# andor: 5561
# andor: 5562
# andor: 5563
# andor: 5564
# andor: 5565
# andor: 5566
# andor: 5567
# andor: 5568
# andor: 5569
# andor: 5570
# andor: 5571
# andor: 5572
# andor: 5573
# andor: 5574
# andor: 5575
# andor: 5576
# andor: 5577
# andor: 5578
# andor: 5579
# andor: 5580
# andor: 5581
# andor: 5582
# andor: 5583
# andor: 5584
# andor: 5585
# andor: 5586
# andor: 5587
# andor: 5588
# andor: 5589
# andor: 5590
# andor: 5591
# andor: 5592
# andor: 5593
# andor: 5594
# andor: 5595
# andor: 5596
# andor: 5597
# andor: 5598
# andor: 5599
# Event number: 5600, Valid shots: 4937
# andor: 5600
# andor: 5601
# andor: 5602
# andor: 5603
# andor: 5604
# andor: 5605
# andor: 5606
# andor: 5607
# andor: 5608
# andor: 5609
# andor: 5610
# andor: 5611
# andor: 5612
# andor: 5613
# andor: 5614
# andor: 5615
# andor: 5616
# andor: 5617
# andor: 5618
# andor: 5619
# andor: 5620
# andor: 5621
# andor: 5622
# andor: 5623
# andor: 5624
# andor: 5625
# andor: 5626
# andor: 5627
# andor: 5628
# andor: 5629
# andor: 5630
# andor: 5631
# andor: 5632
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_8656/1284221534.py in <module>
#     176     smd.save_summary(Nfound=Nfound, Nbad=Nbad)
#     177
# --> 178 smd.done()
#     179
#     180 #if rank == (size - 1):
#
# /cds/sw/ds/ana/conda2/inst/envs/ps-4.4.3/lib/python3.7/site-packages/psana/smalldata.py in done(self)
#     628
#     629         elif self._type == 'serial':
# --> 630             self._server.handle(self._batch)
#     631             self._server.done()
#     632
#
# /cds/sw/ds/ana/conda2/inst/envs/ps-4.4.3/lib/python3.7/site-packages/psana/smalldata.py in handle(self, batch)
#     224                     else:
#     225                         to_backfill.remove(dataset_name)
# --> 226                     self.append_to_cache(dataset_name, data)
#     227
#     228                 for dataset_name in to_backfill:
#
# /cds/sw/ds/ana/conda2/inst/envs/ps-4.4.3/lib/python3.7/site-packages/psana/smalldata.py in append_to_cache(self, dataset_name, data)
#     275             cache = self._cache[dataset_name]
#     276
# --> 277         cache.append(data)
#     278
#     279         if cache.n_events == self.cache_size:
#
# /cds/sw/ds/ana/conda2/inst/envs/ps-4.4.3/lib/python3.7/site-packages/psana/smalldata.py in append(self, data)
#     158
#     159     def append(self, data):
# --> 160         self.data[self.n_events,...] = data
#     161         self.n_events += 1
#     162         return
#
# ValueError: could not broadcast input array from shape (0,) into shape ()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_18035/2704958695.py in <module>
# ----> 1 hasattr(run)
#
# TypeError: hasattr expected 2 arguments, got 1

# %%
print(dir(run))
# Out:
# ['Detector', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_check_empty_calibconst', '_dets', '_evt', '_evt_iter', '_get_runinfo', '_get_valid_env_var_name', '_setup_envstore', 'analyze', 'beginruns', 'c_ana', 'configs', 'detinfo', 'detnames', 'dm', 'dsparms', 'epicsinfo', 'esm', 'events', 'expt', 'id', 'nfiles', 'run', 'runnum', 'scan', 'scaninfo', 'smd_dm', 'smd_fds', 'step', 'steps', 'timestamp', 'xtcinfo']

# %%
print(run.Detector("timing"))
# Out:
# <psana.psexp.run.Run.Detector.<locals>.Container object at 0x7faa86315fd0>

# %%
run.epicsinfo
# Out:
# {('StaleFlags', ''): '',
#  ('IM1K1_power_meter', 'IM1K1:PPM:SPM:VOLT_RBV'): 'IM1K1:PPM:SPM:VOLT_RBV',
#  ('IM1K2_power_meter', 'IM1K2:PPM:SPM:VOLT_RBV'): 'IM1K2:PPM:SPM:VOLT_RBV',
#  ('IM2K1_power_meter', 'IM2K1:PPM:SPM:VOLT_RBV'): 'IM2K1:PPM:SPM:VOLT_RBV',
#  ('IM2K2_power_meter', 'IM2K2:PPM:SPM:VOLT_RBV'): 'IM2K2:PPM:SPM:VOLT_RBV',
#  ('IM3K2_power_meter', 'IM3K2:PPM:SPM:VOLT_RBV'): 'IM3K2:PPM:SPM:VOLT_RBV',
#  ('IM4K2_power_meter', 'IM4K2:PPM:SPM:VOLT_RBV'): 'IM4K2:PPM:SPM:VOLT_RBV',
#  ('IM5K2_power_meter', 'IM5K2:PPM:SPM:VOLT_RBV'): 'IM5K2:PPM:SPM:VOLT_RBV',
#  ('IM6K2_power_meter', 'IM6K2:PPM:SPM:VOLT_RBV'): 'IM6K2:PPM:SPM:VOLT_RBV',
#  ('MONO_MR2K1_PITCH', 'SP1K1:MONO:MMS:M_PI.RBV'): 'SP1K1:MONO:MMS:M_PI.RBV',
#  ('MONO_GRATING_PITCH', 'SP1K1:MONO:MMS:G_PI.RBV'): 'SP1K1:MONO:MMS:G_PI.RBV',
#  ('MONO_GRATING_HORZ', 'SP1K1:MONO:MMS:G_H.RBV'): 'SP1K1:MONO:MMS:G_H.RBV',
#  ('MR1K1_BENDER_US', 'MR1K1:BEND:MMS:US.RBV'): 'MR1K1:BEND:MMS:US.RBV',
#  ('MR1K1_BENDER_DS', 'MR1K1:BEND:MMS:DS.RBV'): 'MR1K1:BEND:MMS:DS.RBV',
#  ('MR1K1_PITCH', 'MR1K1:BEND:MMS:PITCH.RBV'): 'MR1K1:BEND:MMS:PITCH.RBV',
#  ('MR1K2_SWITCH_PITCH',
#   'MR1K2:SWITCH:MMS:PITCH.RBV'): 'MR1K2:SWITCH:MMS:PITCH.RBV',
#  ('EXIT_SLIT_GAP', 'SL1K2:EXIT:MMS:GAP.RBV'): 'SL1K2:EXIT:MMS:GAP.RBV',
#  ('MONO_ENERGY_EV', 'SP1K1:MONO:CALC:ENERGY'): 'SP1K1:MONO:CALC:ENERGY',
#  ('Machine', 'SIOC:SYS0:ML00:AO628'): 'SIOC:SYS0:ML00:AO628',
#  ('milliJoulesPerPulse_gmd',
#   'EM1K0:GMD:HPS:milliJoulesPerPulse'): 'EM1K0:GMD:HPS:milliJoulesPerPulse',
#  ('Keithley_gmd', 'EM1K0:GMD:ETM:01:Reading'): 'EM1K0:GMD:ETM:01:Reading',
#  ('GMD_Keithley_Sum',
#   'EM1K0:GMD:HPS:KeithleySum'): 'EM1K0:GMD:HPS:KeithleySum',
#  ('GMD_Temp_rbv', 'EM1K0:GMD:RTD:1:TEMP_RBV'): 'EM1K0:GMD:RTD:1:TEMP_RBV',
#  ('GMD_CrossSection',
#   'EM1K0:GMD:HPS:CrossSection'): 'EM1K0:GMD:HPS:CrossSection',
#  ('GMD_MeanCharge', 'EM1K0:GMD:HPS:MeanCharge'): 'EM1K0:GMD:HPS:MeanCharge',
#  ('GMD_PressureCalc',
#   'EM1K0:GMD:GSR:1:Calib:Pressure:Calc'): 'EM1K0:GMD:GSR:1:Calib:Pressure:Calc',
#  ('GMD_ElectronMultiplier',
#   'EM2K0:XGMD:SHV:01:M0:C15:VoltageMeasure'): 'EM2K0:XGMD:SHV:01:M0:C15:VoltageMeasure',
#  ('GMD_IonMesh',
#   'EM2K0:XGMD:SHV:01:M0:C14:VoltageMeasure'): 'EM2K0:XGMD:SHV:01:M0:C14:VoltageMeasure',
#  ('GMD_ElectronMesh',
#   'EM2K0:XGMD:SHV:01:M0:C0:VoltageMeasure'): 'EM2K0:XGMD:SHV:01:M0:C0:VoltageMeasure',
#  ('GMD_ElectronFaradayCup',
#   'EM2K0:XGMD:SHV:01:M0:C1:VoltageMeasure'): 'EM2K0:XGMD:SHV:01:M0:C1:VoltageMeasure',
#  ('Keithley_1_xgmd', 'EM2K0:XGMD:ETM:01:Reading'): 'EM2K0:XGMD:ETM:01:Reading',
#  ('Keithley_2_xgmd', 'EM2K0:XGMD:ETM:02:Reading'): 'EM2K0:XGMD:ETM:02:Reading',
#  ('milliJoulesPerPulse_xgmd',
#   'EM2K0:XGMD:HPS:milliJoulesPerPulse'): 'EM2K0:XGMD:HPS:milliJoulesPerPulse',
#  ('XGMD_KeithleySum',
#   'EM2K0:XGMD:HPS:KeithleySum'): 'EM2K0:XGMD:HPS:KeithleySum',
#  ('XGMD_Temp', 'EM2K0:XGMD:RTD:1:TEMP_RBV'): 'EM2K0:XGMD:RTD:1:TEMP_RBV',
#  ('XGMD_CrossSection',
#   'EM2K0:XGMD:HPS:CrossSection'): 'EM2K0:XGMD:HPS:CrossSection',
#  ('XGMD_MeanCharge', 'EM2K0:XGMD:HPS:MeanCharge'): 'EM2K0:XGMD:HPS:MeanCharge',
#  ('XGMD_Pressure',
#   'EM2K0:XGMD:GSR:1:Calib:Pressure:Calc'): 'EM2K0:XGMD:GSR:1:Calib:Pressure:Calc',
#  ('XGMD_ElectronMultiplier',
#   'EM2K0:XGMD:SHV:01:M0:C13:VoltageMeasure'): 'EM2K0:XGMD:SHV:01:M0:C13:VoltageMeasure',
#  ('XGMD_IonMesh',
#   'EM2K0:XGMD:SHV:01:M0:C12:VoltageMeasure'): 'EM2K0:XGMD:SHV:01:M0:C12:VoltageMeasure',
#  ('XGMD_ElectronMesh',
#   'EM2K0:XGMD:SHV:01:M0:C2:VoltageMeasure'): 'EM2K0:XGMD:SHV:01:M0:C2:VoltageMeasure',
#  ('XGMD_ElectronFaradayCup',
#   'EM2K0:XGMD:SHV:01:M0:C3:VoltageMeasure'): 'EM2K0:XGMD:SHV:01:M0:C3:VoltageMeasure',
#  ('AT1K0_photon_energy',
#   'AT1K0:GAS:PhotonEnergy_RBV'): 'AT1K0:GAS:PhotonEnergy_RBV',
#  ('AT1K0_actual_GasAttenTrans', 'AT1K0:GAS:TRANS_RBV'): 'AT1K0:GAS:TRANS_RBV',
#  ('AT1K0_set_GasAttenTrans', 'AT1K0:GAS:TRANS_SP'): 'AT1K0:GAS:TRANS_SP',
#  ('AT1K0_PressureSetPt', 'AT1K0:GAS:TRANS_SP_RBV'): 'AT1K0:GAS:TRANS_SP_RBV',
#  ('AT1K0_VCN70_PosReq',
#   'AT1K0:GAS:VCN:70:POS_REQ'): 'AT1K0:GAS:VCN:70:POS_REQ',
#  ('pf1k0_y', 'PF1K0:WFS:MMS:Y.RBV'): 'PF1K0:WFS:MMS:Y.RBV',
#  ('pf1k0_z', 'PF1K0:WFS:MMS:Z.RBV'): 'PF1K0:WFS:MMS:Z.RBV',
#  ('MR1K4_xup', 'MR1K4:SOMS:MMS:XUP.RBV'): 'MR1K4:SOMS:MMS:XUP.RBV',
#  ('MR1K4_yup', 'MR1K4:SOMS:MMS:YUP.RBV'): 'MR1K4:SOMS:MMS:YUP.RBV',
#  ('MR1K4_pitch', 'MR1K4:SOMS:MMS:PITCH.RBV'): 'MR1K4:SOMS:MMS:PITCH.RBV',
#  ('MR2K4_x', 'MR2K4:KBO:MMS:X.RBV'): 'MR2K4:KBO:MMS:X.RBV',
#  ('MR2K4_y', 'MR2K4:KBO:MMS:Y.RBV'): 'MR2K4:KBO:MMS:Y.RBV',
#  ('MR2K4_pitch', 'MR2K4:KBO:MMS:PITCH.RBV'): 'MR2K4:KBO:MMS:PITCH.RBV',
#  ('MR2K4_bender_us', 'MR2K4:KBO:MMS:BEND:US.RBV'): 'MR2K4:KBO:MMS:BEND:US.RBV',
#  ('MR2K4_bender_ds', 'MR2K4:KBO:MMS:BEND:DS.RBV'): 'MR2K4:KBO:MMS:BEND:DS.RBV',
#  ('MR3K4_x', 'MR3K4:KBO:MMS:X.RBV'): 'MR3K4:KBO:MMS:X.RBV',
#  ('MR3K4_y', 'MR3K4:KBO:MMS:Y.RBV'): 'MR3K4:KBO:MMS:Y.RBV',
#  ('MR3K4_pitch', 'MR3K4:KBO:MMS:PITCH.RBV'): 'MR3K4:KBO:MMS:PITCH.RBV',
#  ('MR3K4_bender_us', 'MR3K4:KBO:MMS:BEND:US.RBV'): 'MR3K4:KBO:MMS:BEND:US.RBV',
#  ('MR3K4_bender_ds', 'MR3K4:KBO:MMS:BEND:DS.RBV'): 'MR3K4:KBO:MMS:BEND:DS.RBV',
#  ('PF1K4_y', 'PF1K4:WFS:MMS:Y.RBV'): 'PF1K4:WFS:MMS:Y.RBV',
#  ('PF1K4_z', 'PF1K4:WFS:MMS:Z.RBV'): 'PF1K4:WFS:MMS:Z.RBV',
#  ('IM2K4_XrayPower', 'IM2K4:PPM:SPM:VOLT_RBV'): 'IM2K4:PPM:SPM:VOLT_RBV',
#  ('IM3K4_XrayPower', 'IM3K4:PPM:SPM:VOLT_RBV'): 'IM3K4:PPM:SPM:VOLT_RBV',
#  ('IM4K4_XrayPower', 'IM4K4:PPM:SPM:VOLT_RBV'): 'IM4K4:PPM:SPM:VOLT_RBV',
#  ('IM5K4_XrayPower', 'IM5K4:PPM:SPM:VOLT_RBV'): 'IM5K4:PPM:SPM:VOLT_RBV',
#  ('CRIX_CRYO_X', 'CRIX:CRYO:MMS:X.RBV'): 'CRIX:CRYO:MMS:X.RBV',
#  ('CRIX_CRYO_Y', 'CRIX:CRYO:MMS:Y.RBV'): 'CRIX:CRYO:MMS:Y.RBV',
#  ('CRIX_CRYO_Z', 'CRIX:CRYO:MMS:Z.RBV'): 'CRIX:CRYO:MMS:Z.RBV',
#  ('CRIX_CRYO_RY', 'CRIX:CRYO:MMS:RY.RBV'): 'CRIX:CRYO:MMS:RY.RBV',
#  ('CRIX_DIAG_X', 'CRIX:DPL:MMS:X.RBV'): 'CRIX:DPL:MMS:X.RBV',
#  ('CRIX_DIAG_Y', 'CRIX:DPL:MMS:Y.RBV'): 'CRIX:DPL:MMS:Y.RBV',
#  ('CRIX_DIAG_Z', 'CRIX:DPL:MMS:Z.RBV'): 'CRIX:DPL:MMS:Z.RBV',
#  ('CRIX_PDET_2THETA', 'CRIX:PDET:MMS:THETA.RBV'): 'CRIX:PDET:MMS:THETA.RBV',
#  ('CRIX_PDET_Y', 'CRIX:PDET:MMS:Y.RBV'): 'CRIX:PDET:MMS:Y.RBV',
#  ('LAKESHORE_A_CRYO_TEMP',
#   'CRIX:USR:TCT:01:GET_TEMP_A'): 'CRIX:USR:TCT:01:GET_TEMP_A',
#  ('LAKESHORE_B_SAMPLE_TEMP',
#   'CRIX:USR:TCT:01:GET_TEMP_B'): 'CRIX:USR:TCT:01:GET_TEMP_B',
#  ('LAKESHORE_C_MAGNET_TEMP',
#   'CRIX:USR:TCT:01:GET_TEMP_C'): 'CRIX:USR:TCT:01:GET_TEMP_C',
#  ('LAKESHORE_D_SPARE_TEMP',
#   'CRIX:USR:TCT:01:GET_TEMP_D'): 'CRIX:USR:TCT:01:GET_TEMP_D',
#  ('Vitara_1_bucket', 'SIOC:SYS0:ML03:AO126'): 'SIOC:SYS0:ML03:AO126',
#  ('Vitara_2_bucket', 'SIOC:SYS0:ML03:AO127'): 'SIOC:SYS0:ML03:AO127',
#  ('Pulse_delay', 'SIOC:SYS0:ML00:CALC510'): 'SIOC:SYS0:ML00:CALC510',
#  ('LAS_VIT_TIME',
#   'LAS:FS14:VIT:FS_TGT_TIME_DIAL'): 'LAS:FS14:VIT:FS_TGT_TIME_DIAL',
#  ('ATM_delay_stage', 'LM2K2:COM_MP2_DLY1'): 'LM2K2:COM_MP2_DLY1',
#  ('LAS_ATT1_WP1', 'LM2K2:INJ_MP1_ATT1_WP1'): 'LM2K2:INJ_MP1_ATT1_WP1',
#  ('LAS_ATT1_WP2', 'LM2K2:INJ_MP1_ATT1_WP2'): 'LM2K2:INJ_MP1_ATT1_WP2'}

# %%
run.dir
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_18035/2500558324.py in <module>
# ----> 1 run.dir
#
# AttributeError: 'RunSerial' object has no attribute 'dir'
